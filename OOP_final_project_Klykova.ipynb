# %% [markdown]
# # Глагольное управление в классах
# ### Выполнила Елизавета Клыкова, БКЛ-181
#
# **Требования:**
# * 2 ✔ – Использование классов: *метакласс Word, классы Verb, Noun, Preposition; класс Combination для сочетаний.*
# * 2 ✔ – Использование наследования: *Verb, Noun и Preposition наследуются от Word.*
# * 1 ✔ – Три библиотеки из тех, что приходится ставить своими руками: *tqdm, conllu, deeppavlov*
# * 2 ✔ "Синтаксический сахар" Питона (декораторы, перегрузка операторов, исключения, примочки из последнего стандарта, ...): *переопределение len() для ConlluReader, исключение ConlluNotLoaded*
# * 1 ✔ – Юнит-тесты: *тест для ConlluReader, тест удаления комбинаций*
# * 2 **?** – Красивая структура классов, проекта, решения; субъективное мнение преподавателя.
# * 1 ✘ – Шаблоны проектирования.
# * 1 ✔ – Бонусы: *непосильный труд по записи пар :)*
#
# **Материалы с пар:**
# * полезное про [классы](https://github.com/klyshinsky/Object_Oriented_Python_2022_23/blob/main/lecture_20220924_operators_decorators.ipynb)
# * [наследование](https://github.com/klyshinsky/Object_Oriented_Python_2022_23/blob/main/lecture_20221008_Inheritance.ipynb)
# * [юнит-тесты](https://github.com/klyshinsky/Object_Oriented_Python_2022_23/blob/main/lecture_20221022_unittest.ipynb)
# * [шаблоны проектирования](https://github.com/klyshinsky/Object_Oriented_Python_2022_23/blob/main/lecture_20221126_design_patterns.ipynb)

# %%
# !pip install tqdm
# !pip install conllu
# !pip install razdel
# !pip install deeppavlov --user
# !python -m deeppavlov install syntax_ru_syntagrus_bert
# !python -m deeppavlov install morpho_ru_syntagrus_pymorphy

# %%
import conllu
import random
import unittest
from conllu.exceptions import ParseException
from tqdm.auto import tqdm
from collections import Counter, OrderedDict
from pprint import pprint

import re
import json
import os
from deeppavlov import build_model, configs
from razdel import sentenize, tokenize
from conllu import parse

# %% [markdown]
# #### Не перезапускаю в целях экономии времени

# %%
dp_model = build_model('ru_syntagrus_joint_parsing', download=True)

# %%
def analyze_text(text):
    parsed_sentences = []
    if len(text) > 65 and not re.match('https?://', text):
        sentences = [sent.text for sent in list(sentenize(text))]
        for sent in sentences:
            tokens = [token.text for token in list(tokenize(sent))]
            if len(tokens) < 400:
                parsed_sentences.append((sent, parse(dp_model([tokens])[0])[0]))
    return parsed_sentences

# %%
def write_to_conllu(parsed_texts, name):
    with open(name, 'w', encoding = 'utf-8') as f:
        for sent in parsed_texts:
            f.write('# text = ' + sent[0] + '\n')
            f.write(sent[1].serialize())

# %%
def make_conllu(file_in, file_out):
    with open(file_in, 'r', encoding='utf-8') as f:
        for line in tqdm(f.readlines()):
            texts = analyze_text(line)
            if texts:
                write_to_conllu(texts, file_out)

# %% [markdown]
# ### Считываем разметку в формате .conllu

# %%
class ConlluReader:

    def __init__(self, filename, encoding='utf-8'):
        self.filename = filename
        self.encoding = encoding

    def load(self):
        with open(self.filename, 'r', encoding=self.encoding) as f:
            paragraphs = f.read().strip().split('\n\n')
            self.paragraphs = paragraphs

    def parse(self):
        self.load()
        self.tokenlists = []
        # исправлен прошлогодний костыль -- теперь не вылетает ParseException
        for paragraph in tqdm(self.paragraphs):
            parts = paragraph.split('\n1\t')
            clean_par = parts[0].replace('\n', '') + '\n1\t' + parts[1]
            try:
                self.tokenlists.extend([tokenlist for tokenlist
                                        in conllu.parse(clean_par)])
            except ParseException:
                print('The data is not formatted correctly:')
                print(paragraph)
                break
        return self.tokenlists

    # переопределение, исключение
    def __len__(self):
        if hasattr(self, 'paragraphs'):
            return len(self.paragraphs)
        else:
            raise ConlluNotLoadedError

# %%
class ConlluNotLoadedError(Exception):
    def __init__(self, message='Call .load() to load the file contents first'):
        self.message = message
        super().__init__(self.message)

# %% [markdown]
# ### Юнит-тесты

# %%
class TestConlluReader(unittest.TestCase):

    def setUp(self):
        print('Setting up ConlluReader...')
        self.conllu = ConlluReader('testfile.CONLLU')

    @classmethod
    def setUpClass(cls):
        print('Setting up the class...')

    def tearDown(self):
        print('Tearing down...')

    def doCleanups(self):
        print('Cleaning up...')

    def testLoad(self):
        print('Testing load function...')
        self.conllu.load()
        self.assertIsInstance(self.conllu.paragraphs, list)
        print('Finished testing load function...')

    def testParse(self):
        print('Testing parse function...')
        self.conllu.parse()
        self.assertIsInstance(self.conllu.tokenlists, list)
        self.assertIsInstance(self.conllu.tokenlists[0],
                              conllu.models.TokenList)
        print('Finished testing parse function...')

    def testData(self):
        print('Testing data completeness...')
        self.conllu.parse()
        self.assertEqual(len(self.conllu.paragraphs),
                         len(self.conllu.tokenlists))
        print('Finished testing data completeness...')

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# testData (__main__.TestConlluReader) ...
# Setting up the class...
# Setting up ConlluReader...
# Testing data completeness...
#   0%|          | 0/20823 [00:00<?, ?it/s]
# ok
# testLoad (__main__.TestConlluReader) ... ok
# testParse (__main__.TestConlluReader) ...
# Finished testing data completeness...
# Tearing down...
# Cleaning up...
# Setting up ConlluReader...
# Testing load function...
# Finished testing load function...
# Tearing down...
# Cleaning up...
# Setting up ConlluReader...
# Testing parse function...
#   0%|          | 0/20823 [00:00<?, ?it/s]
# Finished testing parse function...
# Tearing down...
# Cleaning up...
# ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 13.975s
#
# OK

# %% [markdown]
# #### Загружаем данные

# %%
markup = ConlluReader('articles_Vestnik_rayona.CONLLU')

# %%
len(markup)
# Out:
# ---------------------------------------------------------------------------
# ConlluNotLoadedError                      Traceback (most recent call last)
# C:\Temp/ipykernel_18596/91723240.py in <module>
# ----> 1 len(markup)
#
# C:\Temp/ipykernel_18596/3336415118.py in __len__(self)
#      31             return len(self.paragraphs)
#      32         else:
# ---> 33             raise ConlluNotLoadedError
#
# ConlluNotLoadedError: Call .load() to load the file contents first

# %%
markup.load()
len(markup)
# Out:
# 20823

# %%
tokenlists = markup.parse()
# Out:
#   0%|          | 0/20823 [00:00<?, ?it/s]

# %% [markdown]
# ### Классы: глаголы, существительные, предлоги

# %%
class Word:

    def __init__(self, lemma, pos, form=None, head=None):
        self.lemma = lemma
        self.pos = pos
        self.form = form
        self.head = head

        self.freq = 0
        self.children = Counter()
        self.seen_in = []

# %%
class Verb(Word):

    verb_dict = {}

    def __init__(self, lemma, pos='VERB', form=None, head=None):
        super().__init__(lemma, pos, form, head)
        # обновляем список глаголов
        Verb.verb_dict[lemma] = self

    @classmethod
    def getAllVerbs(cls):
        freq_dict = {verb.lemma: verb.freq
                     for verb in list(cls.verb_dict.values())}
        return dict(sorted(freq_dict.items(),
                           key=lambda item: item[1], reverse=True))

    @classmethod
    def delAllVerbs(cls):
        cls.verb_dict = {}

# %%
class Noun(Word):

    noun_dict = {}

    def __init__(self, lemma, case, number, animacy, deprel, form,
                 head=None, pos='NOUN'):
        super().__init__(lemma, pos, form, head)
        self.case = case
        self.number = number
        self.animacy = animacy
        self.deprel = deprel
        # обновляем список существительных
        noun_key = lemma + '_' + case + '_' + \
            number + '_' + animacy + '_' + deprel
        Noun.noun_dict[noun_key] = self

# %%
class Preposition(Word):

    # предлоги будут уникальны не сами по себе, а в связке с глаголами
    # т.е. бежать-к и обращаться-к -- два разных предлога
    prep_dict = {}

    def __init__(self, lemma, pos='ADP', form=None, head=None):
        super().__init__(lemma, pos, form, head)
        # обновляем список глаголов
        Preposition.prep_dict[lemma] = self

# %% [markdown]
# #### Кладем информацию в классы
# **Проблема:** диппавлов считает, что предлог зависит от существительного. Мировое лингвистическое сообщество считает наоборот. Будем переворачивать.

# %%
def put_words_in_classes(markup):
    # проходим по разборам предложений
    for i, tokens in tqdm(enumerate(markup.tokenlists)):
        sent_id = i  # имитируем уникальное id предложения

        # проходим по токенам предложения
        for token in tokens:

            if token['upos'] == 'VERB':  # нашли глагол
                v_lemma = token['lemma'].lower()
                v_children = []  # сюда положим классы предлогов

                # ищем в токенах зависимые глагола
                for v_child in tokens:
                    if v_child['head'] == token['id']:
                        # глаголы с негативной полярностью
                        if v_child['form'].lower() == 'не':
                            v_lemma = 'не_' + v_lemma
                        # проверяем, что класса для этого глагола еще нет
                        if v_lemma not in Verb.verb_dict:
                            v_as_class = Verb(v_lemma)
                        else:
                            v_as_class = Verb.verb_dict[v_lemma]
                            v_as_class.freq += 1
                            v_as_class.seen_in.append(sent_id)

                        # зависимые существительные, кроме подлежащих (субъектов)
                        if (v_child['upos'] == 'NOUN' or v_child['upos'] == 'PROPN') and v_child['deprel'] != 'nsubj':
                            n_lemma = v_child['lemma'].lower()  # нашли существительное
                            n_form = v_child['form'].lower()
                            try:
                                n_case = v_child['feats']['Case']
                                n_number = v_child['feats']['Number']
                                n_animacy = v_child['feats']['Animacy']
                            except (TypeError, KeyError):
                                n_case, n_number, n_animacy = 'UNK'
                            n_deprel = v_child['deprel']

                            # проверяем, что класса для этого существительного еще нет
                            n_key = '_'.join([n_lemma, n_case, n_number, n_animacy, n_deprel])
                            if n_key not in Noun.noun_dict:
                                n_as_class = Noun(n_lemma, n_case, n_number, n_animacy, n_deprel, n_form)
                            else:
                                n_as_class = Noun.noun_dict[n_key]
                            n_as_class.freq += 1
                            n_as_class.seen_in.append(sent_id)

                            # ищем зависимые предлоги у каждого существительного
                            # если это прямое дополнение, предлога нет
                            p_lemma = '0'
                            p_children = []
                            for n_child in tokens:
                                if n_child['head'] == v_child['id']:
                                    if n_child['upos'] == 'ADP' and n_child['deprel'] == 'case':
                                        p_lemma = n_child['lemma'].lower()  # нашли предлог
                                        # отлавливаем составные предлоги
                                        for p_child in tokens:
                                            try:
                                                if p_child['head'] == n_child['id'] and p_child['deprel'] == 'fixed':
                                                    p_lemma += ' ' + p_child['form'].lower()
                                            except KeyError:
                                                pass

                            p_lemma = v_lemma + '_' + p_lemma
                            # проверяем, что класса для этого предлога еще нет
                            if p_lemma not in Preposition.prep_dict:
                                # родитель предлога -- глагол
                                p_as_class = Preposition(p_lemma, v_as_class)
                            else:
                                p_as_class = Preposition.prep_dict[p_lemma]
                                p_as_class.freq += 1
                                p_as_class.seen_in.append(sent_id)

                            # родитель существительного -- предлог
                            n_as_class.head = p_as_class

                            # предлоги -- дети глаголов, имена -- дети предлогов
                            v_children.append(p_as_class)
                            p_children.append(n_as_class)

                            # обновляем Counter предлога зависимыми-существительными
                            p_as_class.children.update(p_children)
                # обновляем Counter глагола зависимыми-предлогами
                v_as_class.children.update(v_children)

# %%
put_words_in_classes(markup)
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# #### Что же получилось?

# %%
len(Verb.verb_dict)
# Out:
# 4051

# %%
Verb.getAllVerbs()
# Out:
# {'стать': 2660,
#  'состояться': 1902,
#  'пройти': 1579,
#  'мочь': 1463,
#  'быть': 1266,
#  'читать': 1197,
#  'принять': 1174,
#  'получить': 1080,
#  'работать': 1015,
#  'проводиться': 1015,
#  'провести': 876,
#  'проходить': 873,
#  'являться': 866,
#  'находиться': 837,
#  'поступить': 817,
#  'зарегистрировать': 792,
#  'занять': 756,
#  'иметь': 648,
#  'произойти': 635,
#  'рассказать': 617,
#  'жить': 597,
#  'отметить': 588,
#  'составить': 587,
#  'проводить': 583,
#  'прийти': 560,
#  'представить': 549,
#  'составлять': 525,
#  'начать': 524,
#  'посвятить': 512,
#  'установить': 512,
#  'решить': 497,
#  'ждать': 467,
#  'заниматься': 463,
#  'идти': 458,
#  'появиться': 457,
#  'знать': 424,
#  'начаться': 424,
#  'сделать': 423,
#  'говорить': 421,
#  'нет': 421,
#  'оставаться': 412,
#  'принимать': 411,
#  'становиться': 408,
#  'остаться': 394,
#  'вручить': 390,
#  'обратиться': 385,
#  'совершить': 383,
#  'оказаться': 383,
#  'отмечать': 379,
#  'выступить': 376,
#  'смочь': 371,
#  'участвовать': 363,
#  'организовать': 361,
#  'отмечаться': 358,
#  'получать': 356,
#  'сообщить': 352,
#  'прийтись': 351,
#  'открыть': 343,
#  'приходиться': 338,
#  'пригласить': 321,
#  'выйти': 320,
#  'направить': 307,
#  'оказать': 307,
#  'дать': 299,
#  'родиться': 295,
#  'найти': 295,
#  'стоить': 295,
#  'связать': 293,
#  'сказать': 290,
#  'помочь': 289,
#  'предоставить': 285,
#  'приехать': 281,
#  'представлять': 278,
#  'проживать': 275,
#  'любить': 273,
#  'внести': 271,
#  'продолжать': 268,
#  'вести': 262,
#  'считать': 261,
#  'показать': 260,
#  'обучаться': 253,
#  'взять': 249,
#  'собраться': 245,
#  'подготовить': 243,
#  'узнать': 242,
#  'хотеть': 242,
#  'играть': 240,
#  'побывать': 240,
#  'возбудить': 237,
#  'обнаружить': 235,
#  'создать': 234,
#  'наградить': 232,
#  'приходить': 224,
#  'предусмотреть': 222,
#  'погибнуть': 221,
#  'подвести': 213,
#  'учиться': 212,
#  'выбрать': 212,
#  'подарить': 211,
#  'занимать': 211,
#  'вестись': 210,
#  'давать': 209,
#  'нанести': 208,
#  'хотеться': 206,
#  'признать': 206,
#  'начинать': 206,
#  'гореть': 205,
#  'достаться': 205,
#  'назвать': 204,
#  'войти': 204,
#  'приступить': 203,
#  'делать': 199,
#  'помогать': 197,
#  'прибыть': 195,
#  'иметься': 193,
#  'увидеть': 193,
#  'вернуться': 189,
#  'называться': 189,
#  'желать': 188,
#  'бывать': 187,
#  'планироваться': 187,
#  'отправиться': 185,
#  'уйти': 183,
#  'пойти': 182,
#  'считаться': 182,
#  'рассказывать': 181,
#  'завоевать': 180,
#  'стоять': 179,
#  'видеть': 179,
#  'построить': 178,
#  'готовиться': 178,
#  'относиться': 175,
#  'стартовать': 174,
#  'не_мочь': 173,
#  'привести': 173,
#  'попасть': 171,
#  'состоять': 171,
#  'стараться': 168,
#  'выделить': 167,
#  'объявить': 166,
#  'собрать': 165,
#  'вступить': 165,
#  'предложить': 164,
#  'выходить': 163,
#  'расти': 163,
#  'казаться': 162,
#  'брать': 161,
#  'посетить': 161,
#  'собираться': 160,
#  'касаться': 159,
#  'назначить': 156,
#  'называть': 156,
#  'завершить': 152,
#  'принести': 152,
#  'пострадать': 151,
#  'входить': 151,
#  'выбирать': 149,
#  'удаться': 149,
#  'ездить': 149,
#  'зависеть': 149,
#  'происходить': 146,
#  'ходить': 146,
#  'пользоваться': 144,
#  'выявить': 144,
#  'поздравить': 144,
#  'определить': 143,
#  'ожидать': 143,
#  'измениться': 142,
#  'приобрести': 142,
#  'увеличиться': 142,
#  'ответить': 142,
#  'доставить': 140,
#  'успеть': 140,
#  'поставить': 140,
#  'исполниться': 140,
#  'оставить': 138,
#  'устроить': 138,
#  'убрать': 138,
#  'приглашать': 137,
#  'писать': 137,
#  'продолжаться': 137,
#  'обращаться': 136,
#  'не_быть': 135,
#  'следовать': 135,
#  'выступать': 135,
#  'думать': 133,
#  'начинаться': 133,
#  'сидеть': 133,
#  'действовать': 133,
#  'случиться': 132,
#  'привлечь': 132,
#  'оформить': 132,
#  'предстоять': 132,
#  'трудиться': 130,
#  'посещать': 130,
#  'появляться': 130,
#  'помнить': 128,
#  'достигнуть': 127,
#  'подать': 126,
#  'использовать': 124,
#  'выполнить': 124,
#  'вырасти': 124,
#  'мечтать': 123,
#  'позвонить': 122,
#  'стремиться': 121,
#  'нуждаться': 121,
#  'нравиться': 120,
#  'выиграть': 120,
#  'окончить': 119,
#  'просить': 117,
#  'уходить': 114,
#  'существовать': 114,
#  'произвести': 113,
#  'попросить': 112,
#  'заметить': 112,
#  'присутствовать': 112,
#  'приниматься': 109,
#  'написать': 108,
#  'отличаться': 107,
#  'сложиться': 107,
#  'сдать': 106,
#  'утвердить': 106,
#  'вызывать': 105,
#  'избить': 105,
#  'отправить': 105,
#  'завершиться': 105,
#  'открыться': 105,
#  'обсуждаться': 104,
#  'набрать': 104,
#  'приезжать': 103,
#  'обойтись': 103,
#  'слышать': 102,
#  'выполнять': 102,
#  'держать': 102,
#  'напомнить': 101,
#  'встретить': 100,
#  'выписывать': 100,
#  'радовать': 100,
#  'передать': 97,
#  'носить': 96,
#  'выехать': 95,
#  'проявить': 95,
#  'требовать': 94,
#  'ознакомить': 94,
#  'поздравлять': 94,
#  'оставлять': 93,
#  'выезжать': 93,
#  'готовить': 92,
#  'встретиться': 92,
#  'прожить': 92,
#  'нести': 92,
#  'звать': 91,
#  'превышать': 91,
#  'осуществляться': 90,
#  'предлагать': 90,
#  'вспоминать': 90,
#  'требоваться': 90,
#  'лежать': 89,
#  'пытаться': 89,
#  'напоминать': 88,
#  'вызвать': 88,
#  'позволять': 88,
#  'встать': 88,
#  'звучать': 88,
#  'бороться': 87,
#  'не_знать': 87,
#  'найтись': 87,
#  'подлежать': 87,
#  'получиться': 86,
#  'планировать': 86,
#  'проработать': 86,
#  'справиться': 85,
#  'умереть': 85,
#  'смотреть': 85,
#  'исполняться': 85,
#  'перейти': 84,
#  'надеяться': 83,
#  'показывать': 83,
#  'уделяться': 83,
#  'сдавать': 83,
#  'встречаться': 82,
#  'заключить': 82,
#  'возникать': 82,
#  'спешить': 82,
#  'служить': 82,
#  'продлиться': 82,
#  'приурочить': 82,
#  'отдыхать': 81,
#  'включить': 81,
#  'призвать': 81,
#  'производиться': 81,
#  'позволить': 80,
#  'поступать': 79,
#  'наступить': 79,
#  'поддерживать': 79,
#  'продолжить': 78,
#  'оборудовать': 78,
#  'спасти': 78,
#  'похитить': 78,
#  'купить': 78,
#  'задержать': 78,
#  'обеспечивать': 78,
#  'ставить': 78,
#  'дарить': 78,
#  'не_иметь': 77,
#  'выпасть': 77,
#  'подписать': 77,
#  'пожелать': 77,
#  'не_смочь': 76,
#  'способствовать': 76,
#  'приносить': 76,
#  'возникнуть': 76,
#  'сообщать': 76,
#  'встречать': 76,
#  'понимать': 76,
#  'превысить': 75,
#  'обещать': 75,
#  'уменьшиться': 74,
#  'бояться': 74,
#  'осуществлять': 74,
#  'создавать': 73,
#  'отдать': 73,
#  'оказывать': 73,
#  'обеспечить': 72,
#  'разместить': 72,
#  'выпить': 71,
#  'выразить': 71,
#  'управлять': 71,
#  'хранить': 70,
#  'согласиться': 70,
#  'включать': 70,
#  'возложить': 70,
#  'положить': 70,
#  'развиваться': 70,
#  'рассмотреть': 69,
#  'не_стать': 69,
#  'заявить': 69,
#  'отвечать': 69,
#  'закрыть': 68,
#  'искать': 68,
#  'вносить': 68,
#  'получаться': 68,
#  'обмолотить': 68,
#  'потерять': 67,
#  'реализовать': 67,
#  'упасть': 66,
#  'принадлежать': 66,
#  'подойти': 66,
#  'производить': 65,
#  'снять': 65,
#  'понравиться': 64,
#  'строить': 64,
#  'скончаться': 64,
#  'вспомнить': 64,
#  'уметь': 64,
#  'привезти': 64,
#  'присудить': 64,
#  'присвоить': 64,
#  'посадить': 64,
#  'приводить': 63,
#  'послужить': 63,
#  'находить': 63,
#  'собирать': 63,
#  'отличиться': 63,
#  'подняться': 63,
#  'покупать': 62,
#  'следить': 62,
#  'переехать': 61,
#  'обладать': 61,
#  'увеличить': 61,
#  'чувствовать': 61,
#  'съехаться': 61,
#  'публиковать': 60,
#  'повредить': 60,
#  'исполнять': 60,
#  'отремонтировать': 60,
#  'ожидаться': 60,
#  'заболеть': 60,
#  'закончить': 60,
#  'предоставлять': 60,
#  'учить': 60,
#  'ехать': 59,
#  'потребоваться': 59,
#  'услышать': 59,
#  'устанавливаться': 59,
#  'запретить': 59,
#  'предпочитать': 59,
#  'страдать': 59,
#  'задать': 59,
#  'одержать': 59,
#  'прекратить': 58,
#  'рекомендовать': 58,
#  'не_остаться': 58,
#  'поместить': 58,
#  'удовлетворить': 58,
#  'познакомиться': 58,
#  'присоединиться': 58,
#  'забыть': 58,
#  'выписать': 58,
#  'подписаться': 58,
#  'запланировать': 58,
#  'прочитать': 58,
#  'ввести': 58,
#  'складываться': 58,
#  'распространяться': 57,
#  'подтвердить': 57,
#  'подтверждать': 57,
#  'рассчитать': 57,
#  'употреблять': 56,
#  'понять': 56,
#  'исполнить': 56,
#  'сыграть': 56,
#  'злоупотреблять': 55,
#  'проверить': 55,
#  'объяснить': 55,
#  'охватить': 55,
#  'реализоваться': 55,
#  'воспользоваться': 55,
#  'располагаться': 55,
#  'прозвучать': 55,
#  'проявлять': 55,
#  'поделиться': 55,
#  'значить': 55,
#  'справляться': 54,
#  'зайти': 54,
#  'оценить': 54,
#  'защищать': 54,
#  'благодарить': 54,
#  'общаться': 54,
#  'оснастить': 54,
#  'соревноваться': 54,
#  'не_справиться': 53,
#  'продавать': 53,
#  'обсудить': 53,
#  'увлекаться': 53,
#  'воспитываться': 53,
#  'раскрыть': 52,
#  'возглавлять': 52,
#  'просиять': 51,
#  'причинить': 51,
#  'приготовить': 51,
#  'лишить': 51,
#  'образовать': 51,
#  'предоставляться': 51,
#  'поговорить': 51,
#  'решать': 50,
#  'изменить': 50,
#  'уступить': 50,
#  'случаться': 50,
#  'предусматривать': 50,
#  'выглядеть': 50,
#  'подходить': 50,
#  'рассматриваться': 50,
#  'разыгрываться': 50,
#  'протекать': 49,
#  'пояснить': 49,
#  'отсутствовать': 49,
#  'наблюдать': 49,
#  'испытывать': 49,
#  'праздновать': 49,
#  'посмотреть': 48,
#  'судить': 48,
#  'зафиксировать': 48,
#  'забрать': 48,
#  'утверждать': 48,
#  'говориться': 48,
#  'оценивать': 48,
#  'набирать': 48,
#  'делиться': 47,
#  'столкнуться': 47,
#  'платить': 47,
#  'заставить': 47,
#  'состязаться': 47,
#  'довестись': 47,
#  'украсть': 46,
#  'поддержать': 46,
#  'устраивать': 46,
#  'оказываться': 46,
#  'длиться': 46,
#  'защитить': 46,
#  'насчитываться': 46,
#  'воспитывать': 46,
#  'поприветствовать': 46,
#  'означать': 46,
#  'царить': 46,
#  'вывести': 45,
#  'наблюдаться': 45,
#  'попытаться': 45,
#  'перекинуться': 45,
#  'разработать': 45,
#  'возвращаться': 45,
#  'содержать': 45,
#  'руководить': 45,
#  'предназначить': 45,
#  'перенести': 45,
#  'порадовать': 45,
#  'не_оставлять': 44,
#  'дойти': 44,
#  'ловиться': 44,
#  'жаловаться': 44,
#  'радоваться': 44,
#  'повезти': 44,
#  'учредить': 44,
#  'разбить': 43,
#  'задумываться': 43,
#  'нарушать': 43,
#  'содержаться': 43,
#  'разрешить': 43,
#  'предлагаться': 43,
#  'слушать': 43,
#  'обсуждать': 43,
#  'разыграть': 43,
#  'постараться': 42,
#  'спать': 42,
#  'подниматься': 42,
#  'менять': 42,
#  'привыкнуть': 42,
#  'приобретать': 42,
#  'сохранить': 42,
#  'повысить': 41,
#  'заготовить': 41,
#  'посеять': 41,
#  'использоваться': 41,
#  'заложить': 41,
#  'грозить': 41,
#  'проникнуть': 41,
#  'не_выбрать': 41,
#  'уделять': 41,
#  'научиться': 41,
#  'обходиться': 41,
#  'коснуться': 41,
#  'размещаться': 41,
#  'изъять': 40,
#  'не_стоить': 40,
#  'закончиться': 40,
#  'поменять': 40,
#  'заменить': 40,
#  'почтить': 40,
#  'воспитать': 40,
#  'забывать': 40,
#  'обратить': 39,
#  'двигаться': 39,
#  'отдавать': 39,
#  'признаться': 39,
#  'выплачиваться': 39,
#  'удостоить': 39,
#  'изготовить': 39,
#  'заключаться': 39,
#  'выдать': 38,
#  'поднять': 38,
#  'проснуться': 38,
#  'пить': 38,
#  'покинуть': 38,
#  'живить': 38,
#  'отказаться': 38,
#  'гордиться': 38,
#  'убедиться': 38,
#  'попробовать': 38,
#  'волновать': 38,
#  'болеть': 38,
#  'ловить': 38,
#  'храниться': 37,
#  'увеличиваться': 37,
#  'украсить': 37,
#  'повыситься': 37,
#  'поблагодарить': 37,
#  'информировать': 37,
#  'предполагаться': 37,
#  'погасить': 36,
#  'потратить': 36,
#  'нарушить': 36,
#  'выплатить': 36,
#  'превратиться': 36,
#  'запрещаться': 36,
#  'хватать': 36,
#  'демонстрировать': 36,
#  'перестать': 36,
#  'выдаваться': 35,
#  'запомниться': 35,
#  'мешать': 35,
#  'применяться': 35,
#  'спросить': 35,
#  'захватить': 35,
#  'наметить': 35,
#  'обустроить': 35,
#  'продемонстрировать': 35,
#  'сократиться': 35,
#  'победить': 35,
#  'перевести': 35,
#  'окружать': 35,
#  'улыбнуться': 35,
#  'посвящать': 34,
#  'уехать': 34,
#  'добиться': 34,
#  'настать': 34,
#  'пережить': 34,
#  'пополниться': 34,
#  'выигрывать': 34,
#  'висеть': 34,
#  'тянуться': 34,
#  'вводиться': 34,
#  'проиграть': 34,
#  'тушить': 33,
#  'вынести': 33,
#  'избрать': 33,
#  'почувствовать': 33,
#  'ударить': 33,
#  'сопровождаться': 33,
#  'соответствовать': 33,
#  'заработать': 33,
#  'ознакомиться': 33,
#  'основать': 33,
#  'отдохнуть': 33,
#  'познакомить': 33,
#  'уволить': 32,
#  'закрепить': 32,
#  'садиться': 32,
#  'покончить': 32,
#  'применить': 32,
#  'понадобиться': 32,
#  'не_давать': 32,
#  'ощущаться': 32,
#  'браться': 32,
#  'перечислить': 32,
#  'бежать': 32,
#  'шить': 32,
#  'насчитывать': 32,
#  'замечать': 32,
#  'не_успеть': 31,
#  'расследовать': 31,
#  'повлечь': 31,
#  'звонить': 31,
#  'обращать': 31,
#  'допустить': 31,
#  'заняться': 31,
#  'объяснять': 31,
#  'тянуть': 31,
#  'верить': 31,
#  'учитываться': 31,
#  'функционировать': 31,
#  'пообщаться': 31,
#  'решаться': 31,
#  'доверять': 30,
#  'хватить': 30,
#  'поработать': 30,
#  'соблюдать': 30,
#  'разойтись': 30,
#  'сформировать': 30,
#  'не_обойтись': 30,
#  'совершать': 30,
#  'наказываться': 30,
#  'остановить': 30,
#  'учитывать': 30,
#  'украшать': 30,
#  'устроиться': 30,
#  'не_хватать': 30,
#  'вставать': 30,
#  'удивить': 30,
#  'обслуживать': 30,
#  'приглашаться': 30,
#  'изучать': 30,
#  'петь': 30,
#  'вырастить': 30,
#  'доходить': 30,
#  'даваться': 30,
#  'последовать': 30,
#  'пустить': 30,
#  'опубликовать': 30,
#  'вынудить': 29,
#  'топить': 29,
#  'участиться': 29,
#  'выделяться': 29,
#  'признаваться': 29,
#  'мыть': 29,
#  'жалеть': 29,
#  'преобразиться': 29,
#  'затратить': 29,
#  'ощущать': 29,
#  'обучать': 29,
#  'сталкиваться': 29,
#  'выпустить': 29,
#  'наносить': 28,
#  'развернуть': 28,
#  'загореться': 28,
#  'возобновить': 28,
#  'допускаться': 28,
#  'исходить': 28,
#  'завести': 28,
#  'не_измениться': 28,
#  'окунуться': 28,
#  'записать': 28,
#  'преподавать': 28,
#  'не_забыть': 28,
#  'оплачивать': 28,
#  'обожать': 28,
#  'переходить': 27,
#  'выясниться': 27,
#  'сработать': 27,
#  'не_предусмотреть': 27,
#  'возить': 27,
#  'побежать': 27,
#  'убирать': 27,
#  'достигать': 27,
#  'испытать': 27,
#  'навестить': 27,
#  'открываться': 27,
#  'танцевать': 27,
#  'прислать': 27,
#  'востребовать': 27,
#  'переименовать': 27,
#  'спрашивать': 27,
#  'выдавать': 27,
#  'накрыть': 26,
#  'не_хотеть': 26,
#  'пропасть': 26,
#  'указать': 26,
#  'убить': 26,
#  'приостановить': 26,
#  'меняться': 26,
#  'сократить': 26,
#  'заботиться': 26,
#  'распахнуть': 26,
#  'интересоваться': 26,
#  'интересовать': 26,
#  'засеять': 26,
#  'задействовать': 26,
#  'восстановить': 26,
#  'подводить': 26,
#  'задуматься': 26,
#  'накопиться': 26,
#  'начисляться': 26,
#  'лечить': 26,
#  'определять': 26,
#  'провожать': 26,
#  'делаться': 26,
#  'застать': 25,
#  'чувствоваться': 25,
#  'остановиться': 25,
#  'наслаждаться': 25,
#  'свидетельствовать': 25,
#  'отменить': 25,
#  'сохраняться': 25,
#  'пролететь': 25,
#  'выращивать': 25,
#  'привить': 25,
#  'ухаживать': 25,
#  'разыгрывать': 25,
#  'приветствовать': 25,
#  'влиять': 25,
#  'сложить': 25,
#  'обозначить': 25,
#  'владеть': 25,
#  'держаться': 25,
#  'вручать': 25,
#  'привлекать': 25,
#  'наступать': 25,
#  'объявлять': 25,
#  'заслужить': 25,
#  'объединить': 24,
#  'голосовать': 24,
#  'праздноваться': 24,
#  'потушить': 24,
#  'гибнуть': 24,
#  'уничтожить': 24,
#  'узнавать': 24,
#  'удаваться': 24,
#  'расположить': 24,
#  'лечь': 24,
#  'обязать': 24,
#  'снизиться': 24,
#  'проиндексировать': 24,
#  'завезти': 24,
#  'организовывать': 24,
#  'продолжиться': 24,
#  'разделить': 24,
#  'распределить': 24,
#  'увлечь': 24,
#  'не_сказать': 24,
#  'доставлять': 23,
#  'кормить': 23,
#  'взяться': 23,
#  'отбывать': 23,
#  'подвергать': 23,
#  'бить': 23,
#  'числиться': 23,
#  'бросить': 23,
#  'сорвать': 23,
#  'ложиться': 23,
#  'обследовать': 23,
#  'ухудшиться': 23,
#  'отводиться': 23,
#  'насытить': 23,
#  'знакомиться': 23,
#  'рекомендоваться': 23,
#  'осмотреть': 23,
#  'вывезти': 23,
#  'переполнить': 23,
#  'убеждаться': 23,
#  'объединять': 23,
#  'характеризоваться': 22,
#  'скрыться': 22,
#  'выяснить': 22,
#  'гулять': 22,
#  'устанавливать': 22,
#  'не_думать': 22,
#  'развести': 22,
#  'озвучить': 22,
#  'заканчиваться': 22,
#  'поспешить': 22,
#  'повлиять': 22,
#  'снимать': 22,
#  'доставать': 22,
#  'окружить': 22,
#  'записаться': 22,
#  'заполнить': 22,
#  'запечатлеть': 22,
#  'возрастать': 22,
#  'открывать': 22,
#  'оцениваться': 22,
#  'терпеть': 22,
#  'поощрить': 22,
#  'завершаться': 22,
#  'отзываться': 22,
#  'освоить': 22,
#  'забить': 22,
#  'попадать': 22,
#  'возрасти': 22,
#  'уступать': 22,
#  'сохраниться': 22,
#  'рассматривать': 21,
#  'не_отличаться': 21,
#  'откликнуться': 21,
#  'не_удаться': 21,
#  'продать': 21,
#  'уберечь': 21,
#  'явиться': 21,
#  'показаться': 21,
#  'выставить': 21,
#  'торговать': 21,
#  'подключить': 21,
#  'не_пить': 21,
#  'преодолеть': 21,
#  'изучить': 21,
#  'контролировать': 21,
#  'надеть': 21,
#  'осваивать': 21,
#  'надевать': 21,
#  'затронуть': 21,
#  'предшествовать': 21,
#  'придумать': 21,
#  'чествовать': 21,
#  'ассоциироваться': 21,
#  'ощутить': 21,
#  'не_сидеть': 21,
#  'намолачивать': 21,
#  'огородить': 20,
#  'засыпать': 20,
#  'осудить': 20,
#  'пополнить': 20,
#  'закрываться': 20,
#  'посоветовать': 20,
#  'рассчитывать': 20,
#  'направляться': 20,
#  'таить': 20,
#  'кататься': 20,
#  'побеседовать': 20,
#  'вручаться': 20,
#  'обновить': 20,
#  'поселиться': 20,
#  'отправлять': 20,
#  'житься': 20,
#  'не_забывать': 20,
#  'удостоиться': 20,
#  'сеять': 20,
#  'не_бывать': 20,
#  'не_проходить': 20,
#  'разбудить': 19,
#  'избежать': 19,
#  'увезти': 19,
#  'проезжать': 19,
#  'образоваться': 19,
#  'поделить': 19,
#  'поражать': 19,
#  'проверять': 19,
#  'применять': 19,
#  'заглянуть': 19,
#  'оперировать': 19,
#  'развить': 19,
#  'молиться': 19,
#  'не_получить': 19,
#  'развивать': 19,
#  'раздаваться': 19,
#  'не_считать': 19,
#  'уезжать': 19,
#  'указывать': 19,
#  'выдержать': 19,
#  'заинтересовать': 19,
#  'заслушать': 19,
#  'рисовать': 19,
#  'освятить': 19,
#  'не_жалеть': 19,
#  'выполняться': 19,
#  'задолжать': 19,
#  'пустовать': 19,
#  'раскидать': 19,
#  'избегать': 19,
#  'поглядывать': 19,
#  'кипеть': 19,
#  'создаваться': 19,
#  'предусматриваться': 19,
#  'объясняться': 18,
#  'обстоять': 18,
#  'полагаться': 18,
#  'вернуть': 18,
#  'занести': 18,
#  'наказать': 18,
#  'отравиться': 18,
#  'не_представляться': 18,
#  'удивлять': 18,
#  'лидировать': 18,
#  'попадаться': 18,
#  'пропадать': 18,
#  'пропускать': 18,
#  'пасть': 18,
#  'отказать': 18,
#  'проголосовать': 18,
#  'добиваться': 18,
#  'проделать': 18,
#  'набраться': 18,
#  'растить': 18,
#  'приступать': 18,
#  'закупить': 18,
#  'не_желать': 18,
#  'отстаивать': 18,
#  'подорожать': 18,
#  'накопить': 18,
#  'подводиться': 18,
#  'переносить': 18,
#  'надоить': 18,
#  'предпринять': 17,
#  'предотвратить': 17,
#  'не_вернуться': 17,
#  'отпустить': 17,
#  'утерять': 17,
#  'выпускать': 17,
#  'предстать': 17,
#  'знакомить': 17,
#  'вывозить': 17,
#  'не_допускаться': 17,
#  'оплатить': 17,
#  'предполагать': 17,
#  'не_дать': 17,
#  'не_выходить': 17,
#  'глядеть': 17,
#  'продаваться': 17,
#  'ремонтироваться': 17,
#  'скучать': 17,
#  'подвергнуться': 17,
#  'отслужить': 17,
#  'запустить': 17,
#  'помешать': 17,
#  'разделиться': 17,
#  'покорить': 17,
#  'сменить': 17,
#  'удивляться': 17,
#  'варьироваться': 17,
#  'присылать': 17,
#  'определяться': 17,
#  'разместиться': 17,
#  'почитать': 17,
#  'сесть': 17,
#  'познать': 17,
#  'приложить': 17,
#  'забросить': 17,
#  'расширить': 17,
#  'гласить': 17,
#  'пополняться': 17,
#  'включаться': 17,
#  'надаивать': 17,
#  'оправдывать': 17,
#  'крыться': 16,
#  'не_заметить': 16,
#  'выпивать': 16,
#  'разговаривать': 16,
#  'предъявить': 16,
#  'не_уступить': 16,
#  'вырубить': 16,
#  'сбить': 16,
#  'не_закрываться': 16,
#  'обойти': 16,
#  'унести': 16,
#  'начислить': 16,
#  'снизить': 16,
#  'умирать': 16,
#  'дополнить': 16,
#  'уклоняться': 16,
#  'привлекаться': 16,
#  'совершаться': 16,
#  'отложить': 16,
#  'проложить': 16,
#  ...}

# %%
len(Noun.noun_dict)
# Out:
# 11839

# %%
list(Noun.noun_dict.keys())[-130:-120]
# Out:
# ['сказка_Loc_Sing_Inan_advcl',
#  'свадьба_Ins_Sing_Inan_obl',
#  'откровение_Ins_Plur_Inan_obl',
#  'проза_Nom_Sing_Inan_nsubj:pass',
#  'условие_Nom_Sing_Inan_conj',
#  'письмо_Gen_Plur_Inan_obl',
#  'послание_Acc_Sing_Inan_obj',
#  'спонсорами—магазина_Ins_Plur_Inan_obl',
#  'передача_Acc_Plur_Inan_obl',
#  'блюдо_Acc_Plur_Inan_obj']

# %%
len(Preposition.prep_dict)
# Out:
# 8528

# %%
list(Preposition.prep_dict.keys())[-130:-120]
# Out:
# ['настоящие—сделать_0',
#  'не_настоящие—сделать_из',
#  'цель—предоставить_0',
#  'цель—предоставить_в',
#  'расплатиться_с',
#  'грешить_0',
#  'удаться_из',
#  'возникнуть_по',
#  'заменить_в',
#  'предостеречь_0']

# %% [markdown]
# Откуда-то взялись страшные склеенные леммы. Неужели правда?
#
# ![пример](bad_preposition.jpg)
#
# **На будущее:** диппавлов не понимает тире, приклеенное к словам. Нужно чистить или исправлять перед разметкой.

# %% [markdown]
# ### Сочетания
# Мы получили набор классов, связанных между собой. Как из этого получить сочетания? Можно пройтись снизу вверх по построенным связям. Но делать это каждый раз -- как-то странно и неудобно, особенно если есть классы.

# %%
class Combination():

    # информация о том, что уже встретилось
    comb_dict = {}

    def __init__(self, verb, prep, noun, text):
        self.verb = verb
        self.prep = prep
        self.deprel = noun.deprel
        self.noun = noun
        self.text = text
        self.freq = 0
        self.seen_in = []
        comb_key = '_'.join([verb.lemma, prep.lemma, noun.case, noun.number,
                             noun.animacy, noun.deprel, noun.lemma])
        Combination.comb_dict[comb_key] = self

    @classmethod
    def getAllCombos(cls):
        all_combos = [value.text for value in list(cls.comb_dict.values())]
        return OrderedDict(Counter(all_combos).most_common())

    @classmethod
    def deleteAllCombos(cls):
        cls.comb_dict = {}

# %%
def create_combos():
    for v_lemma, verb in tqdm(list(Verb.verb_dict.items())):
        for prep in verb.children:
            for noun in prep.children:
                comb_key = '_'.join([verb.lemma, prep.lemma.split('_')[-1], noun.case, noun.number, noun.animacy, noun.deprel, noun.lemma])
                if comb_key not in Combination.comb_dict:
                    text = ' '.join([verb.lemma, prep.lemma.split('_')[-1], noun.form])
                    comb = Combination(verb, prep, noun, text)
                    comb.freq += 1
                else:
                    comb = Combination.comb_dict[comb_key]
                    comb.freq += 1

# %%
create_combos()
# Out:
#   0%|          | 0/4051 [00:00<?, ?it/s]

# %%
Combination.getAllCombos()
# Out:
# OrderedDict([('составить 0 млн', 5),
#              ('обучаться 0 сош', 5),
#              ('занять 0 место', 4),
#              ('не_занять 0 место', 4),
#              ('не_зарегистрировать 0 дтп', 4),
#              ('отметить 0 день', 3),
#              ('набрать 0 воды', 3),
#              ('составлять 0 руб', 3),
#              ('составлять 0 га', 3),
#              ('составить 0 тысяч', 3),
#              ('составить 0 руб', 3),
#              ('установить 0 лицо', 3),
#              ('возбудить 0 дела', 3),
#              ('выявить 0 факт', 3),
#              ('отмечаться 0 день', 3),
#              ('зарегистрировать 0 дтп', 3),
#              ('не_иметь 0 детей', 3),
#              ('представить 0 команды', 3),
#              ('не_представить 0 команды', 3),
#              ('заключить 0 договора', 3),
#              ('не_установить 0 лицо', 3),
#              ('завоевать 0 место', 3),
#              ('просиять 0 п', 2),
#              ('быть 0 летом', 2),
#              ('быть с стороны', 2),
#              ('получить 0 свидетельства', 2),
#              ('учиться 0 класса', 2),
#              ('жить в п', 2),
#              ('провести 0 раз', 2),
#              ('провести 0 рейд', 2),
#              ('провести 0 ряд', 2),
#              ('провести 0 работы', 2),
#              ('провести 0 исследования', 2),
#              ('провести 0 мастер-класс', 2),
#              ('провести 0 день', 2),
#              ('провести 0 мероприятие', 2),
#              ('провести 0 мероприятия', 2),
#              ('провести 0 совещание', 2),
#              ('провести 0 конкурс', 2),
#              ('провести 0 соревнования', 2),
#              ('принять 0 меры', 2),
#              ('принять 0 заявление', 2),
#              ('принять 0 решение', 2),
#              ('принять 0 заявления', 2),
#              ('организовать 0 мероприятие', 2),
#              ('организовать 0 соревнования', 2),
#              ('стать 0 победителем', 2),
#              ('стать 0 призерами', 2),
#              ('стать 0 человеком', 2),
#              ('стать в году', 2),
#              ('иметь 0 детей', 2),
#              ('иметь 0 детей-инвалидов', 2),
#              ('проводить 0 неделю', 2),
#              ('проводить 0 отпуска', 2),
#              ('проводить 0 день', 2),
#              ('определить 0 победителя', 2),
#              ('отметить 0 год', 2),
#              ('отметить 0 работы', 2),
#              ('доставить 0 человек', 2),
#              ('не_доставить 0 человек', 2),
#              ('отмечать 0 год', 2),
#              ('набрать 0 процента', 2),
#              ('пройти в воскресенье', 2),
#              ('ждать 0 выпускников', 2),
#              ('ждать 0 чуда', 2),
#              ('ждать 0 любителей', 2),
#              ('произойти в день', 2),
#              ('совершить 0 хищение', 2),
#              ('совершить 0 наезд', 2),
#              ('совершить 0 преступления', 2),
#              ('совершить 0 проникновение', 2),
#              ('совершить 0 кражи', 2),
#              ('совершить 0 чин', 2),
#              ('связать 0 жизнь', 2),
#              ('связать 0 деятельность', 2),
#              ('решить 0 вопрос', 2),
#              ('составлять 0 метров', 2),
#              ('составлять 0 рублей', 2),
#              ('составлять 0 тысяч', 2),
#              ('составлять 0 км', 2),
#              ('составлять 0 тонн', 2),
#              ('назвать 0 имена', 2),
#              ('назвать 0 цифры', 2),
#              ('стараться в очередь', 2),
#              ('направить 0 заявления', 2),
#              ('не_быть с стороны', 2),
#              ('заготовить 0 тонн', 2),
#              ('составить 0 рублей', 2),
#              ('составить 0 процента', 2),
#              ('составить 0 млрд', 2),
#              ('составить 0 миллионов', 2),
#              ('составить согласно данным', 2),
#              ('посеять 0 культуры', 2),
#              ('проводиться 0 мероприятия', 2),
#              ('проводиться 0 раз', 2),
#              ('проводиться 0 день', 2),
#              ('внести 0 представления', 2),
#              ('внести 0 изменения', 2),
#              ('внести 0 поправки', 2),
#              ('собрать 0 детей', 2),
#              ('собрать 0 любителей', 2),
#              ('занять в итоге', 2),
#              ('занять 0 места', 2),
#              ('наградить 0 победители', 2),
#              ('оставить 0 часть', 2),
#              ('устранить 0 нарушения', 2),
#              ('оборудовать 0 места', 2),
#              ('наступить после употребления', 2),
#              ('закрыть 0 дверь', 2),
#              ('разбить 0 стекло', 2),
#              ('разбить 0 стекла', 2),
#              ('обнаружить 0 труп', 2),
#              ('обнаружить 0 тело', 2),
#              ('подвести 0 итоги', 2),
#              ('не_подвести 0 итоги', 2),
#              ('не_огородить 0 забором', 2),
#              ('устанавливаться 0 лица', 2),
#              ('украсть 0 колеса', 2),
#              ('оказать 0 помощь', 2),
#              ('оказать 0 црб', 2),
#              ('поставить 0 диагноз', 2),
#              ('накрыть 0 стол', 2),
#              ('открыть 0 сезон', 2),
#              ('открыть 0 двери', 2),
#              ('открыть 0 счет', 2),
#              ('найти 0 игрушки', 2),
#              ('спасти 0 жизнь', 2),
#              ('установить 0 личность', 2),
#              ('установить 0 лица', 2),
#              ('установить 0 место', 2),
#              ('установить 0 обстоятельства', 2),
#              ('привлечь 0 лица', 2),
#              ('прибыть в п', 2),
#              ('дать 0 сигнал', 2),
#              ('дать 0 возможность', 2),
#              ('дать 0 старт', 2),
#              ('дать 0 разъяснения', 2),
#              ('дать 0 ответ', 2),
#              ('возбудить 0 отделом', 2),
#              ('предусмотреть 0 тыс', 2),
#              ('похитить 0 мотоцикл', 2),
#              ('стоить 0 рублей', 2),
#              ('предпринять 0 меры', 2),
#              ('написать 0 романов', 2),
#              ('написать 0 стихотворение', 2),
#              ('предоставить 0 возможность', 2),
#              ('предоставить 0 магазином', 2),
#              ('изменить 0 номер', 2),
#              ('выявить 0 нарушения', 2),
#              ('выявить 0 факторы', 2),
#              ('выявить 0 победителей', 2),
#              ('увеличить 0 срок', 2),
#              ('запретить 0 курение', 2),
#              ('не_стать 0 жертвой', 2),
#              ('не_стать 0 исключением', 2),
#              ('не_стать 0 лет', 2),
#              ('не_стать 0 победителем', 2),
#              ('не_стать 0 призерами', 2),
#              ('не_стать 0 человеком', 2),
#              ('не_стоить 0 рублей', 2),
#              ('вынести 0 приговор', 2),
#              ('нанести 0 повреждения', 2),
#              ('нанести 0 побои', 2),
#              ('поздравить 0 дам', 2),
#              ('сделать 0 вывод', 2),
#              ('сделать 0 многое', 2),
#              ('сделать 0 шаг', 2),
#              ('сделать 0 шаги', 2),
#              ('сделать 0 фото', 2),
#              ('проходить в регионах', 2),
#              ('выразить 0 отношение', 2),
#              ('выполнить 0 мероприятия', 2),
#              ('выполнить 0 разряд', 2),
#              ('выполнить 0 план', 2),
#              ('завершить 0 расследование', 2),
#              ('завершить 0 работы', 2),
#              ('завершить 0 посев', 2),
#              ('назначить 0 пособие', 2),
#              ('погибнуть в авариях', 2),
#              ('отмечаться 0 праздник', 2),
#              ('подвергать 0 опасности', 2),
#              ('зарегистрировать в эл', 2),
#              ('обучаться 0 техникума', 2),
#              ('обучаться 0 классов', 2),
#              ('обучаться 0 класса', 2),
#              ('обучаться 0 школы', 2),
#              ('обучаться 0 аст', 2),
#              ('отдать 0 годы', 2),
#              ('отдать 0 предпочтение', 2),
#              ('причинить 0 вред', 2),
#              ('произвести 0 ремонт', 2),
#              ('произвести 0 тонн', 2),
#              ('удовлетворить 0 требования', 2),
#              ('возложить 0 цветы', 2),
#              ('уполномочить 0 полиции', 2),
#              ('становиться 0 раз', 2),
#              ('становиться в время', 2),
#              ('вырубить 0 деревьев', 2),
#              ('утвердить 0 план', 2),
#              ('утвердить 0 правила', 2),
#              ('не_закрываться на замок', 2),
#              ('устроить 0 праздник', 2),
#              ('построить 0 дом', 2),
#              ('дойти до рублей', 2),
#              ('не_иметь 0 детей-инвалидов', 2),
#              ('не_иметь 0 образования', 2),
#              ('не_иметь 0 представления', 2),
#              ('не_иметь 0 возможности', 2),
#              ('не_обнаружить 0 труп', 2),
#              ('не_обнаружить 0 тело', 2),
#              ('не_обойтись без спиртного', 2),
#              ('представить 0 район', 2),
#              ('представить 0 работ', 2),
#              ('представить 0 работы', 2),
#              ('отправить 0 человек', 2),
#              ('отправить из района', 2),
#              ('отменить 0 переход', 2),
#              ('не_представить 0 район', 2),
#              ('не_представить 0 работ', 2),
#              ('не_представить 0 работы', 2),
#              ('не_предусмотреть 0 ответственность', 2),
#              ('не_предусмотреть 0 кодексом', 2),
#              ('не_предусмотреть 0 тыс', 2),
#              ('подарить 0 внуков', 2),
#              ('живить 0 лес', 2),
#              ('снизить 0 уровень', 2),
#              ('объявить 0 конкурс', 2),
#              ('желать без ограничений', 2),
#              ('приготовить 0 подарки', 2),
#              ('обеспечить 0 доступ', 2),
#              ('достигнуть 0 рублей', 2),
#              ('помочь 0 словом', 2),
#              ('лишить 0 родителей', 2),
#              ('не_обеспечить 0 оснащение', 2),
#              ('не_обеспечить 0 доступ', 2),
#              ('заключить 0 соглашение', 2),
#              ('заключить 0 договор', 2),
#              ('не_допускаться 0 расторжение', 2),
#              ('заболеть 0 орви', 2),
#              ('остановить 0 автомобиль', 2),
#              ('не_оборудовать 0 места', 2),
#              ('не_оборудовать 0 сигнализацией', 2),
#              ('уплатить 0 пени', 2),
#              ('достаться 0 пирамиде', 2),
#              ('не_организовать 0 мероприятие', 2),
#              ('не_организовать 0 соревнования', 2),
#              ('не_организовать 0 сбор', 2),
#              ('не_найти 0 игрушки', 2),
#              ('убрать 0 культуры', 2),
#              ('не_заниматься 0 организацией', 2),
#              ('уделяться 0 деятельности', 2),
#              ('оценить 0 труд', 2),
#              ('не_дать в обиду', 2),
#              ('превысить в году', 2),
#              ('подать 0 заявление', 2),
#              ('подать 0 заявки', 2),
#              ('подать 0 заявления', 2),
#              ('не_установить 0 личность', 2),
#              ('не_установить 0 лица', 2),
#              ('не_установить 0 место', 2),
#              ('не_установить 0 обстоятельства', 2),
#              ('не_установить 0 срок', 2),
#              ('озвучить 0 цифры', 2),
#              ('не_пользоваться 0 популярностью', 2),
#              ('создать 0 пункты', 2),
#              ('создать 0 условия', 2),
#              ('создать 0 места', 2),
#              ('представлять в числе', 2),
#              ('не_представлять в числе', 2),
#              ('присудить 0 место', 2),
#              ('присудить 0 титул', 2),
#              ('захватить 0 флаг', 2),
#              ('присвоить 0 звание', 2),
#              ('подписать 0 указ', 2),
#              ('подписать 0 приказ', 2),
#              ('вручить 0 удостоверение', 2),
#              ('вручить 0 награды', 2),
#              ('вручить 0 дипломы', 2),
#              ('вручить 0 билеты', 2),
#              ('вручить 0 подарки', 2),
#              ('вручить 0 благодарности', 2),
#              ('вручить 0 диплом', 2),
#              ('вручить 0 медаль', 2),
#              ('вручить 0 документ', 2),
#              ('вручить 0 свидетельства', 2),
#              ('вручить 0 сертификаты', 2),
#              ('вручить 0 грамоты', 2),
#              ('вручить 0 медали', 2),
#              ('завоевать среди девушек', 2),
#              ('обходиться по подсчетам', 2),
#              ('выиграть 0 партии', 2),
#              ('не_занять 0 места', 2),
#              ('превышать по итогам', 2),
#              ('записать 0 ребенка', 2),
#              ('выделить 0 место', 2),
#              ('выделить 0 средства', 2),
#              ('выделить 0 путевок', 2),
#              ('выделить 0 млн', 2),
#              ('выделить 0 тысяч', 2),
#              ('удостоить 0 звания', 2),
#              ('засеять 0 га', 2),
#              ('засеять 0 гектаров', 2),
#              ('учредить 0 орден', 2),
#              ('не_получить 0 плату', 2),
#              ('не_получить 0 субсидии', 2),
#              ('не_получить 0 свидетельства', 2),
#              ('запланировать 0 мероприятия', 2),
#              ('насчитываться 0 человек', 2),
#              ('издать 0 книга', 2),
#              ('дарить в день', 2),
#              ('воспитывать 0 детей', 2),
#              ('воспитать 0 детей', 2),
#              ('не_зарегистрировать в эл', 2),
#              ('уделить 0 внимание', 2),
#              ('затронуть 0 вопросы', 2),
#              ('не_входить в программу', 2),
#              ('не_входить в состав', 2),
#              ('вырастить 0 детей', 2),
#              ('не_собрать 0 детей', 2),
#              ('не_собрать 0 любителей', 2),
#              ('не_назвать 0 имена', 2),
#              ('не_назвать 0 цифры', 2),
#              ('поощрить 0 учеников', 2),
#              ('рассчитать на детей', 2),
#              ('рассчитать на года', 2),
#              ('не_учиться в школах', 2),
#              ('не_учиться 0 класса', 2),
#              ('не_подлежать 0 регистрации', 2),
#              ('не_подлежать 0 призыву', 2),
#              ('разрисовать 0 стены', 2),
#              ('не_разрисовать 0 стены', 2),
#              ('обмолотить 0 хлеба', 2),
#              ('разместить 0 фотографии', 2),
#              ('не_дойти до рублей', 2),
#              ('навести 0 порядок', 2),
#              ('не_сидеть без дела', 2),
#              ('не_сидеть без работы', 2),
#              ('не_становиться 0 раз', 2),
#              ('не_оплачивать 0 счета', 2),
#              ('не_проводиться 0 мероприятия', 2),
#              ('не_проводиться 0 раз', 2),
#              ('не_проводиться 0 день', 2),
#              ('не_решить 0 вопрос', 2),
#              ('приковать 0 внимание', 2),
#              ('отключить 0 отопление', 2),
#              ('не_завершить 0 расследование', 2),
#              ('не_завершить 0 работы', 2),
#              ('не_завершить 0 посев', 2),
#              ('не_приступить к заготовке', 2),
#              ('не_заготовить 0 тонн', 2),
#              ('не_увидеть 0 места', 2),
#              ('случиться в году', 1),
#              ('случиться в начале', 1),
#              ('случиться в п', 1),
#              ('случиться в хозяйстве', 1),
#              ('случиться в г', 1),
#              ('случиться в часов', 1),
#              ('случиться в поселке', 1),
#              ('случиться в месте', 1),
#              ('случиться в доме', 1),
#              ('случиться меньше—в пятницу', 1),
#              ('случиться на километре', 1),
#              ('случиться с утра', 1),
#              ('случиться с жительницей', 1),
#              ('случиться 0 ночью', 1),
#              ('случиться спустя неделю', 1),
#              ('случиться у максима', 1),
#              ('случиться по вине', 1),
#              ('просиять в земле', 1),
#              ('приступить к службе', 1),
#              ('приступить к тушению', 1),
#              ('приступить к работе', 1),
#              ('приступить к разбирательству', 1),
#              ('приступить к работам', 1),
#              ('приступить к обязанностям', 1),
#              ('приступить к погрузке', 1),
#              ('приступить к проектированию', 1),
#              ('приступить к отключению', 1),
#              ('приступить к реализации', 1),
#              ('приступить к уборке', 1),
#              ('приступить к постановке', 1),
#              ('приступить к вручению', 1),
#              ('приступить к разработке', 1),
#              ('приступить к сооружению', 1),
#              ('приступить к рытью', 1),
#              ('приступить к заделке', 1),
#              ('приступить к скашиванию', 1),
#              ('приступить к промывке', 1),
#              ('приступить к посеву', 1),
#              ('приступить к ремонту', 1),
#              ('приступить к выполнению', 1),
#              ('приступить к заготовке', 1),
#              ('приступить к жатве', 1),
#              ('приступить по следам', 1),
#              ('приступить по словам', 1),
#              ('приступить 0 миром', 1),
#              ('приступить 0 осенью', 1),
#              ('приступить в раз', 1),
#              ('приступить в районе', 1),
#              ('приступить в конце', 1),
#              ('приступить в больнице', 1),
#              ('приступить в году', 1),
#              ('приступить в спк', 1),
#              ('приступить в период', 1),
#              ('приступить в молодости', 1),
#              ('приступить в июле', 1),
#              ('приступить в начале', 1),
#              ('приступить в феврале', 1),
#              ('приступить с понедельника', 1),
#              ('приступить с появлением', 1),
#              ('приступить района—в понедельник', 1),
#              ('приступить на станции', 1),
#              ('приступить на неделе', 1),
#              ('приступить на днях', 1),
#              ('приступить после уборки', 1),
#              ('приступить из сельхозпредприятий', 1),
#              ('рассказать в интервью', 1),
#              ('рассказать в огибдд', 1),
#              ('рассказать в отделе', 1),
#              ('рассказать в помещении', 1),
#              ('рассказать в мо', 1),
#              ('рассказать в канун', 1),
#              ('рассказать в номере', 1),
#              ('рассказать в понедельник', 1),
#              ('рассказать в деревне', 1),
#              ('рассказать в очерке', 1),
#              ('рассказать в онд', 1),
#              ('рассказать в докладе', 1),
#              ('рассказать в форме', 1),
#              ('рассказать в беседе', 1),
#              ('рассказать о мерах', 1),
#              ('рассказать о уловках', 1),
#              ('рассказать о работах', 1),
#              ('рассказать о религии', 1),
#              ('рассказать о истории', 1),
#              ('рассказать о судьбе', 1),
#              ('рассказать о киноактёрах', 1),
#              ('рассказать о аспектах', 1),
#              ('рассказать о ситуации', 1),
#              ('рассказать о службе', 1),
#              ('рассказать о итогах', 1),
#              ('рассказать о жизни', 1),
#              ('рассказать о коллегах', 1),
#              ('рассказать о аспекте', 1),
#              ('рассказать о играх', 1),
#              ('рассказать о молодости', 1),
#              ('рассказать о школьнике', 1),
#              ('рассказать о конституции', 1),
#              ('рассказать о власти', 1),
#              ('рассказать о флоре', 1),
#              ('рассказать о куклах', 1),
#              ('рассказать о а', 1),
#              ('рассказать о педагоге', 1),
#              ('рассказать о специфике', 1),
#              ('рассказать о работе', 1),
#              ('рассказать о студентках', 1),
#              ('рассказать о творчестве', 1),
#              ('рассказать о хлопотах', 1),
#              ('рассказать о услугах', 1),
#              ('рассказать о смене', 1),
#              ('рассказать о изменениях', 1),
#              ('рассказать о выставке', 1),
#              ('рассказать о любви', 1),
#              ('рассказать о событии', 1),
#              ('рассказать о успехах', 1),
#              ('рассказать о фестивале', 1),
#              ('рассказать о программе', 1),
#              ('рассказать о деятельности', 1),
#              ('рассказать о церемонии', 1),
#              ('рассказать о перспективах', 1),
#              ('рассказать о волейболе', 1),
#              ('рассказать о результатах', 1),
#              ('рассказать о канонах', 1),
#              ('рассказать о наказаниях', 1),
#              ('рассказать о конструировании', 1),
#              ('рассказать о особенностях', 1),
#              ('рассказать о событиях', 1),
#              ('рассказать о правах', 1),
#              ('рассказать о городе', 1),
#              ('рассказать о ходу', 1),
#              ('рассказать о реализации', 1),
#              ('рассказать о планах', 1),
#              ('рассказать о целях', 1),
#              ('рассказать о буднях', 1),
#              ('рассказать о преимуществах', 1),
#              ('рассказать о методе', 1),
#              ('рассказать о предприятиях', 1),
#              ('рассказать о состоянии', 1),
#              ('рассказать о отдыхе', 1),
#              ('рассказать о порядке', 1),
#              ('рассказать о человеке', 1),
#              ('рассказать 0 соседу', 1),
#              ('рассказать 0 участникам', 1),
#              ('рассказать 0 считалки', 1),
#              ('рассказать 0 воспитанникам', 1),
#              ('рассказать 0 гостям', 1),
#              ('рассказать 0 а', 1),
#              ('рассказать 0 детям', 1),
#              ('рассказать 0 ребятам', 1),
#              ('рассказать 0 школьникам', 1),
#              ('рассказать 0 читателю', 1),
#              ('рассказать 0 руководителя', 1),
#              ('рассказать 0 читателям', 1),
#              ('рассказать 0 многое', 1),
#              ('рассказать 0 руководителей', 1),
#              ('рассказать 0 заведующего', 1),
#              ('рассказать 0 студентам', 1),
#              ('рассказать 0 корреспонденту', 1),
#              ('рассказать 0 историю', 1),
#              ('рассказать про обряды', 1),
#              ('рассказать про семьи', 1),
#              ('рассказать по очереди', 1),
#              ('рассказать за беседой', 1),
#              ('рассказать за годы', 1),
#              ('рассказать на уроке', 1),
#              ('рассказать на экскурсии', 1),
#              ('рассказать на планерке', 1),
#              ('рассказать на встрече', 1),
#              ('рассказать на раз', 1),
#              ('рассказать с помощью презентации', 1),
#              ('рассказать с сцены', 1),
#              ('рассказать в ходе линии', 1),
#              ('стоять в углу', 1),
#              ('стоять в дворе', 1),
#              ('стоять в с', 1),
#              ('стоять в время', 1),
#              ('стоять в парниках', 1),
#              ('стоять в очереди', 1),
#              ('стоять в республике', 1),
#              ('стоять в районе', 1),
#              ('стоять в улицу', 1),
#              ('стоять в форме', 1),
#              ('стоять в ряд', 1),
#              ('стоять в зале', 1),
#              ('стоять в спальне', 1),
#              ('стоять у дома', 1),
#              ('стоять у истоков', 1),
#              ('стоять у станков', 1),
#              ('стоять на веранде', 1),
#              ('стоять на улице', 1),
#              ('стоять на морозе', 1),
#              ('стоять на день', 1),
#              ('стоять на страже', 1),
#              ('стоять на столе', 1),
#              ('стоять на неделе', 1),
#              ('стоять на повестке', 1),
#              ('стоять на месте', 1),
#              ('стоять возле дома', 1),
#              ('стоять под слоем', 1),
#              ('стоять порядок тысяч', 1),
#              ('стоять 0 колом', 1),
#              ('стоять 0 год', 1),
#              ('стоять 0 сорняками', 1),
#              ('стоять без дела', 1),
#              ('стоять по стойке', 1),
#              ('получать 0 образование', 1),
#              ('получать 0 молока', 1),
#              ('получать 0 ранения', 1),
#              ('получать 0 травмы', 1),
#              ('получать 0 травму', 1),
#              ('получать 0 пенсию', 1),
#              ('получать 0 исцеление', 1),
#              ('получать 0 компенсацию', 1),
#              ('получать 0 машинку', 1),
#              ('получать 0 набор', 1),
#              ('получать 0 фен', 1),
#              ('получать 0 диплом', 1),
#              ('получать 0 родителями', 1),
#              ('получать 0 подарков', 1),
#              ('получать 0 количество', 1),
#              ('получать 0 плату', 1),
#              ('получать 0 функции', 1),
#              ('получать 0 урожайность', 1),
#              ('получать 0 стипендию', 1),
#              ('получать 0 номер', 1),
#              ('получать 0 стресс', 1),
#              ('получать 0 статус', 1),
#              ('получать 0 подарки', 1),
#              ('получать 0 пособие', 1),
#              ('получать 0 поздравления', 1),
#              ('получать 0 зерна', 1),
#              ('получать 0 урожаи', 1),
#              ('получать 0 четверки', 1),
#              ('получать 0 признание', 1),
#              ('получать 0 выплату', 1),
#              ('получать 0 капитал', 1),
#              ('получать 0 мед', 1),
#              ('получать 0 письма', 1),
#              ('получать 0 зарплату', 1),
#              ('получать 0 поддержку', 1),
#              ('получать 0 субсидию', 1),
#              ('получать 0 информацию', 1),
#              ('получать 0 сертификат', 1),
#              ('получать 0 приз', 1),
#              ('получать 0 порцию', 1),
#              ('получать 0 сумму', 1),
#              ('получать 0 урожай', 1),
#              ('получать 0 средства', 1),
#              ('получать 0 карточку', 1),
#              ('получать 0 возможность', 1),
#              ('получать 0 нагрузки', 1),
#              ('получать 0 правило', 1),
#              ('получать 0 квитанции', 1),
#              ('получать 0 неделю', 1),
#              ('получать 0 звание', 1),
#              ('получать 0 миллионов', 1),
#              ('получать 0 надои', 1),
#              ('получать 0 рублей', 1),
#              ('получать 0 помощь', 1),
#              ('получать 0 участки', 1),
#              ('получать 0 распространение', 1),
#              ('получать в время', 1),
#              ('получать в субботу', 1),
#              ('получать в дтп', 1),
#              ('получать в подарок', 1),
#              ('получать в дни', 1),
#              ('получать в году', 1),
#              ('получать в результате', 1),
#              ('получать в канун', 1),
#              ('получать в среднем', 1),
#              ('получать в награду', 1),
#              ('получать в конце', 1),
#              ('получать в режиме', 1),
#              ('получать в годы', 1),
#              ('получать в районе', 1),
#              ('получать в половине', 1),
#              ('получать по вторникам', 1),
#              ('получать по линии', 1),
#              ('получать по уходу', 1),
#              ('получать по центнеров', 1),
#              ('получать по месяцев', 1),
#              ('получать по поросенка', 1),
#              ('получать после молитвы', 1),
#              ('получать после обучения', 1),
#              ('получать из с', 1),
#              ('получать из газет', 1),
#              ('получать из точки', 1),
#              ('получать из бюджета', 1),
#              ('получать на трудодни', 1),
#              ('получать на развитие', 1),
#              ('получать на месте', 1),
#              ('получать за рублей', 1),
#              ('получать за трудодень', 1),
#              ('получать за детей', 1),
#              ('получать за опорос', 1),
#              ('получать в соответствии с указанием', 1),
#              ('получать благодаря способностям', 1),
#              ('получать благодаря соблюдению', 1),
#              ('получать с гектара', 1),
#              ('получать с едой', 1),
#              ('получать от учеников', 1),
#              ('получать от книги', 1),
#              ('получать от члена', 1),
#              ('получать от свиноматки', 1),
#              ('получать между конкурсами', 1),
#              ('получать до центнеров', 1),
#              ('получать вместо бюллетеня', 1),
#              ('получать в течение лет', 1),
#              ('получать в виде конверта', 1),
#              ('быть к счастью', 1),
#              ('быть к сожалению', 1),
#              ('быть к примеру', 1),
#              ('быть у происшествия', 1),
#              ('быть у школы', 1),
#              ('быть у школьников', 1),
#              ('быть у валентины', 1),
#              ('быть у представителей', 1),
#              ('быть у детей', 1),
#              ('быть у читателей', 1),
#              ('быть у подписчиков', 1),
#              ('быть у человека', 1),
#              ('быть у жителей', 1),
#              ('быть у народа', 1),
#              ('быть у человек', 1),
#              ('быть у бухгалтеров', 1),
#              ('быть у полиции', 1),
#              ('быть у праздника', 1),
#              ('быть у советчан', 1),
#              ('быть у ребятишек', 1),
#              ('быть у членов', 1),
#              ('быть у веры', 1),
#              ('быть у продуктов', 1),
#              ('быть у участников', 1),
#              ('быть у ларисы', 1),
#              ('быть у ходьбы', 1),
#              ('быть у ребят', 1),
#              ('быть у любы', 1),
#              ('быть у супругов', 1),
#              ('быть у сети', 1),
#              ('быть у булыгиных', 1),
#              ('быть у участника', 1),
#              ('быть у мамы', 1),
#              ('быть у подразделения', 1),
#              ('быть у профессии', 1),
#              ('быть у учреждения', 1),
#              ('быть вблизи берега', 1),
#              ('быть 0 часть', 1),
#              ('быть 0 проблема', 1),
#              ('быть 0 иван', 1),
#              ('быть 0 школе', 1),
#              ('быть 0 сыну', 1),
#              ('быть 0 года', 1),
#              ('быть 0 словом', 1),
#              ('быть 0 люду', 1),
#              ('быть 0 валентине', 1),
#              ('быть 0 событие', 1),
#              ('быть 0 раз', 1),
#              ('быть 0 потребителям', 1),
#              ('быть 0 слова', 1),
#              ('быть 0 зимой', 1),
#              ('быть 0 россиянам', 1),
#              ('быть на пути', 1),
#              ('быть на груди', 1),
#              ('быть на рублей', 1),
#              ('быть на страницах', 1),
#              ('быть на момент', 1),
#              ('быть на плане', 1),
#              ('быть на земле', 1),
#              ('быть на выставке', 1),
#              ('быть на волге', 1),
#              ('быть на мероприятии', 1),
#              ('быть на площадках', 1),
#              ('быть на сайте', 1),
#              ('быть в год', 1),
#              ('быть в погашении', 1),
#              ('быть в доме', 1),
#              ('быть в гараже', 1),
#              ('быть в квартире', 1),
#              ('быть в школе', 1),
#              ('быть в случаях', 1),
#              ('быть в центре', 1),
#              ('быть в поселке', 1),
#              ('быть в россии', 1),
#              ('быть в году', 1),
#              ('быть в странах', 1),
#              ('быть в стране', 1),
#              ('быть в семье', 1),
#              ('быть в детстве', 1),
#              ('быть в школах', 1),
#              ('быть в дни', 1),
#              ('быть в время', 1),
#              ('быть в районе', 1),
#              ('быть в канун', 1),
#              ('быть в комнате', 1),
#              ('быть в времена', 1),
#              ('быть в жизни', 1),
#              ('быть в законодательстве', 1),
#              ('быть в храме', 1),
#              ('быть в поселении', 1),
#              ('быть в пользу', 1),
#              ('быть в больнице', 1),
#              ('быть в хозяйстве', 1),
#              ('быть в записи', 1),
#              ('быть в церкви', 1),
#              ('быть в использовании', 1),
#              ('быть в деревнях', 1),
#              ('быть в деревне', 1),
#              ('быть в системе', 1),
#              ('быть с раза', 1),
#              ('быть с километра', 1),
#              ('быть с детства', 1),
#              ('быть для целей', 1),
#              ('быть при выборе', 1),
#              ('быть при поступлении', 1),
#              ('быть среди выпускников', 1),
#              ('быть среди родственников', 1),
#              ('быть по услугам', 1),
#              ('быть по словам', 1),
#              ('быть по заказу', 1),
#              ('быть помимо взрослых', 1),
#              ('быть помимо вкладов', 1),
#              ('быть помимо плюсов', 1),
#              ('быть за лет', 1),
#              ('быть за часа', 1),
#              ('быть за детьми', 1),
#              ('быть вместо сигарет', 1),
#              ('быть до финиша', 1),
#              ('быть до воды', 1),
#              ('быть до игры', 1),
#              ('быть до пор', 1),
#              ('быть из родника', 1),
#              ('быть возле поворота', 1),
#              ('родиться в году', 1),
#              ('родиться в селе', 1),
#              ('родиться в семье', 1),
#              ('родиться в рубашке', 1),
#              ('родиться в д', 1),
#              ('родиться в деревне', 1),
#              ('родиться в п', 1),
#              ('родиться в эл', 1),
#              ('родиться в день', 1),
#              ('родиться в больнице', 1),
#              ('родиться в районе', 1),
#              ('родиться в годы', 1),
#              ('родиться в г', 1),
#              ('родиться в с', 1),
#              ('родиться в деревеньке', 1),
#              ('родиться в городе', 1),
#              ('родиться в январе', 1),
#              ('родиться в время', 1),
#              ('родиться с весом', 1),
#              ('родиться с собеседником', 1),
#              ('родиться на неделе', 1),
#              ('родиться на тему', 1),
#              ('родиться 0 женщиной', 1),
#              ('родиться 0 мальчиком', 1),
#              ('родиться 0 ребенка', 1),
#              ('родиться 0 ребенком', 1),
#              ('родиться 0 матерью', 1),
#              ('родиться 0 зимой', 1),
#              ('родиться 0 года', 1),
#              ('родиться за период', 1),
#              ('родиться за квартал', 1),
#              ('родиться за год', 1),
#              ('родиться за месяцев', 1),
#              ('родиться из деревни', 1),
#              ('родиться у пары', 1),
#              ('родиться у представителей', 1),
#              ('родиться у ефима', 1),
#              ('родиться через года', 1),
#              ('родиться согласно данным', 1),
#              ('родиться о собеседнике', 1),
#              ('родиться после сына', 1),
#              ('переехать в году', 1),
#              ('переехать в г', 1),
#              ('переехать в здание', 1),
#              ('переехать в жильё', 1),
#              ('переехать в северное', 1),
#              ('переехать в село', 1),
#              ('переехать в михайловку', 1),
#              ('переехать в пос', 1),
#              ('переехать в тц', 1),
#              ('переехать в зал', 1),
#              ('переехать в помещение', 1),
#              ('переехать из домика', 1),
#              ('переехать на родину', 1),
#              ('получить 0 образование', 1),
#              ('получить 0 информацию', 1),
#              ('получить 0 ушиб', 1),
#              ('получить 0 аванс', 1),
#              ('получить 0 повреждения', 1),
#              ('получить 0 ранения', 1),
#              ('получить 0 ожоги', 1),
#              ('получить 0 травму', 1),
#              ('получить 0 травмы', 1),
#              ('получить 0 сообщение', 1),
#              ('получить 0 ссадины', 1),
#              ('получить 0 повреждение', 1),
#              ('получить 0 плату', 1),
#              ('получить 0 переохлаждение', 1),
#              ('получить 0 перелом', 1),
#              ('получить 0 деньги', 1),
#              ('получить 0 ожог', 1),
#              ('получить 0 вечером', 1),
#              ('получить 0 отравление', 1),
#              ('получить 0 приглашения', 1),
#              ('получить 0 акты', 1),
#              ('получить 0 информация', 1),
#              ('получить 0 специальность', 1),
#              ('получить 0 профессию', 1),
#              ('получить 0 набор', 1),
#              ('получить 0 видеорегистратор', 1),
#              ('получить 0 фотокамеру—р', 1),
#              ('получить 0 грант', 1),
#              ('получить 0 поддержку', 1),
#              ('получить 0 аттестат', 1),
#              ('получить 0 диплом', 1),
#              ('получить 0 книги', 1),
#              ('получить 0 награды—знаки', 1),
#              ('получить 0 знаки', 1),
#              ('получить 0 благодарности', 1),
#              ('получить 0 дипломы', 1),
#              ('получить 0 сумму', 1),
#              ('получить 0 свидетельство', 1),
#              ('получить 0 облучение', 1),
#              ('получить 0 пользу', 1),
#              ('получить 0 лицензию', 1),
#              ('получить 0 одобрение', 1),
#              ('получить 0 группу', 1),
#              ('получить 0 ранение', 1),
#              ('получить 0 лечение', 1),
#              ('получить 0 подарки', 1),
#              ('получить 0 принадлежности', 1),
#              ('получить 0 средства', 1),
#              ('получить 0 оценку', 1),
#              ('получить 0 консультацию', 1),
#              ('получить 0 госуслугу', 1),
#              ('получить 0 кубок', 1),
#              ('получить 0 ответы', 1),
#              ('получить 0 награды', 1),
#              ('получить 0 выплату', 1),
#              ('получить 0 воспаление', 1),
#              ('получить 0 уведомлений', 1),
#              ('получить 0 разряд', 1),
#              ('получить 0 приз', 1),
#              ('получить 0 повестки', 1),
#              ('получить 0 отсрочки', 1),
#              ('получить 0 тонн', 1),
#              ('получить 0 толчок', 1),
#              ('получить 0 аттестаты', 1),
#              ('получить 0 справку', 1),
#              ('получить 0 похоронку', 1),
#              ('получить 0 извещение', 1),
#              ('получить 0 известность', 1),
#              ('получить 0 медаль', 1),
#              ('получить 0 советы', 1),
#              ('получить 0 удостоверение', 1),
#              ('получить 0 количество', 1),
#              ('получить 0 сертификаты', 1),
#              ('получить 0 субсидии', 1),
#              ('получить 0 приглашение', 1),
#              ('получить 0 задание', 1),
#              ('получить 0 название', 1),
#              ('получить 0 сертификат', 1),
#              ('получить 0 возможность', 1),
#              ('получить 0 квартиры', 1),
#              ('получить 0 денег', 1),
#              ('получить 0 миллион', 1),
#              ('получить 0 ячменя', 1),
#              ('получить 0 путевок', 1),
#              ('получить 0 информации', 1),
#              ('получить 0 путевки', 1),
#              ('получить 0 наставления', 1),
#              ('получить 0 наименование', 1),
#              ('получить 0 опыт', 1),
#              ('получить 0 титул', 1),
#              ('получить 0 билеты', 1),
#              ('получить 0 права', 1),
#              ('получить 0 категорию', 1),
#              ('получить 0 путевку', 1),
#              ('получить 0 мальчиков', 1),
#              ('получить 0 квартиру', 1),
#              ('получить 0 сувениры', 1),
#              ('получить 0 ответ', 1),
#              ('получить 0 вещи', 1),
#              ('получить 0 пенал', 1),
#              ('получить 0 машинки', 1),
#              ('получить 0 книжки', 1),
#              ('получить 0 наград', 1),
#              ('получить 0 статус', 1),
#              ('получить 0 призы', 1),
#              ('получить 0 грамоты', 1),
#              ('получить 0 отклики', 1),
#              ('получить 0 удовольствие', 1),
#              ('получить 0 анкету', 1),
#              ('получить 0 млн', 1),
#              ('получить 0 мяса', 1),
#              ('получить 0 пенсию', 1),
#              ('получить 0 награду', 1),
#              ('получить 0 распространение', 1),
#              ('получить 0 место', 1),
#              ('получить 0 шарфики', 1),
#              ('получить 0 грамоту', 1),
#              ('получить 0 футболки', 1),
#              ('получить 0 право', 1),
#              ('получить 0 направление', 1),
#              ('получить 0 автомобили', 1),
#              ('получить 0 подарок', 1),
#              ('получить 0 документы', 1),
#              ('получить 0 лет', 1),
#              ('получить 0 консультации', 1),
#              ('получить 0 трактористы-машинисты', 1),
#              ('получить 0 звезду', 1),
#              ('получить 0 заключение', 1),
#              ('получить 0 субсидию', 1),
#              ('получить 0 паспорт', 1),
#              ('получить 0 телефон', 1),
#              ('получить 0 уведомления', 1),
#              ('получить 0 смс-сообщение', 1),
#              ('получить 0 премию', 1),
#              ('получить 0 благодарность', 1),
#              ('получить 0 лист', 1),
#              ('получить 0 услуги', 1),
#              ('получить 0 килограммов', 1),
#              ('получить 0 обморожения', 1),
#              ('получить 0 вознаграждение', 1),
#              ('получить 0 автомобиль', 1),
#              ('получить 0 счет', 1),
#              ('получить 0 килограмма', 1),
#              ('получить 0 штраф', 1),
#              ('получить 0 массу', 1),
#              ('получить 0 разъяснения', 1),
#              ('получить 0 карты', 1),
#              ('получить 0 корочки', 1),
#              ('получить 0 приза', 1),
#              ('получить в результате', 1),
#              ('получить в дтп', 1),
#              ('получить в академии', 1),
#              ('получить в подарок', 1),
#              ('получить в школе', 1),
#              ('получить в день', 1),
#              ('получить в районе', 1),
#              ('получить в деле', 1),
#              ('получить в донецке', 1),
#              ('получить в приезд', 1),
#              ('получить в отделе', 1),
#              ('получить в году', 1),
#              ('получить в целом', 1),
#              ('получить в случае', 1),
#              ('получить в учреждении', 1),
#              ...])

# %% [markdown]
# А если в дверь стучатся злобные синтаксисты, и мы решили срочно все удалить? Сработает ли наша функция? Проверим это.
#
# ### Юнит-тесты 2.0

# %%
class TestCombination(unittest.TestCase):

    def testDeleting(cls):
        print('Testing deleteAllCombos()...')
        Combination.comb_dict = {'not empty dict': 'for checking'}
        Combination.deleteAllCombos()
        cls.assertEqual(Combination.comb_dict, {})
        print('Testing done.')

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# testDeleting (__main__.TestCombination) ... ok
# testData (__main__.TestConlluReader) ...
# Testing deleteAllCombos()...
# Testing done.
# Setting up the class...
# Setting up ConlluReader...
# Testing data completeness...
#   0%|          | 0/20823 [00:00<?, ?it/s]
# ok
# testLoad (__main__.TestConlluReader) ...
# Finished testing data completeness...
# Tearing down...
# Cleaning up...
# Setting up ConlluReader...
# Testing load function...
# Finished testing load function...
# Tearing down...
# Cleaning up...
# ok
# testParse (__main__.TestConlluReader) ...
# Setting up ConlluReader...
# Testing parse function...
#   0%|          | 0/20823 [00:00<?, ?it/s]
# Finished testing parse function...
# Tearing down...
# Cleaning up...
# ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 14.315s
#
# OK

# %%
Combination.deleteAllCombos()

# %%
Combination.getAllCombos()
# Out:
# OrderedDict()

# %% [markdown]
# ### Единый пайплайн -- от файла с текстом до словаря

# %%
def create_government_dict(file_in, file_out):
#     размечаем
#     make_conllu(file_in, file_out)

    # считываем разметку
    markup = ConlluReader(file_out)
    markup.parse()
    put_words_in_classes(markup)
    create_combos()
    pprint(Combination.getAllCombos())

# %%
create_government_dict('articles_Vestnik_rayona.txt',
                       'articles_Vestnik_rayona.conllu')
# Out:
#   0%|          | 0/20823 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/4051 [00:00<?, ?it/s]
# OrderedDict([('составить 0 млн', 5),
#              ('обучаться 0 сош', 5),
#              ('занять 0 место', 4),
#              ('не_занять 0 место', 4),
#              ('не_зарегистрировать 0 дтп', 4),
#              ('отметить 0 день', 3),
#              ('набрать 0 воды', 3),
#              ('составлять 0 руб', 3),
#              ('составлять 0 га', 3),
#              ('составить 0 тысяч', 3),
#              ('составить 0 руб', 3),
#              ('установить 0 лицо', 3),
#              ('возбудить 0 дела', 3),
#              ('выявить 0 факт', 3),
#              ('отмечаться 0 день', 3),
#              ('зарегистрировать 0 дтп', 3),
#              ('не_иметь 0 детей', 3),
#              ('представить 0 команды', 3),
#              ('не_представить 0 команды', 3),
#              ('заключить 0 договора', 3),
#              ('не_установить 0 лицо', 3),
#              ('завоевать 0 место', 3),
#              ('просиять 0 п', 2),
#              ('быть 0 летом', 2),
#              ('быть с стороны', 2),
#              ('получить 0 свидетельства', 2),
#              ('учиться 0 класса', 2),
#              ('жить в п', 2),
#              ('провести 0 раз', 2),
#              ('провести 0 рейд', 2),
#              ('провести 0 ряд', 2),
#              ('провести 0 работы', 2),
#              ('провести 0 исследования', 2),
#              ('провести 0 мастер-класс', 2),
#              ('провести 0 день', 2),
#              ('провести 0 мероприятие', 2),
#              ('провести 0 мероприятия', 2),
#              ('провести 0 совещание', 2),
#              ('провести 0 конкурс', 2),
#              ('провести 0 соревнования', 2),
#              ('принять 0 меры', 2),
#              ('принять 0 заявление', 2),
#              ('принять 0 решение', 2),
#              ('принять 0 заявления', 2),
#              ('организовать 0 мероприятие', 2),
#              ('организовать 0 соревнования', 2),
#              ('стать 0 победителем', 2),
#              ('стать 0 призерами', 2),
#              ('стать 0 человеком', 2),
#              ('стать в году', 2),
#              ('иметь 0 детей', 2),
#              ('иметь 0 детей-инвалидов', 2),
#              ('проводить 0 неделю', 2),
#              ('проводить 0 отпуска', 2),
#              ('проводить 0 день', 2),
#              ('определить 0 победителя', 2),
#              ('отметить 0 год', 2),
#              ('отметить 0 работы', 2),
#              ('доставить 0 человек', 2),
#              ('не_доставить 0 человек', 2),
#              ('отмечать 0 год', 2),
#              ('набрать 0 процента', 2),
#              ('пройти в воскресенье', 2),
#              ('ждать 0 выпускников', 2),
#              ('ждать 0 чуда', 2),
#              ('ждать 0 любителей', 2),
#              ('произойти в день', 2),
#              ('совершить 0 хищение', 2),
#              ('совершить 0 наезд', 2),
#              ('совершить 0 преступления', 2),
#              ('совершить 0 проникновение', 2),
#              ('совершить 0 кражи', 2),
#              ('совершить 0 чин', 2),
#              ('связать 0 жизнь', 2),
#              ('связать 0 деятельность', 2),
#              ('решить 0 вопрос', 2),
#              ('составлять 0 метров', 2),
#              ('составлять 0 рублей', 2),
#              ('составлять 0 тысяч', 2),
#              ('составлять 0 км', 2),
#              ('составлять 0 тонн', 2),
#              ('назвать 0 имена', 2),
#              ('назвать 0 цифры', 2),
#              ('стараться в очередь', 2),
#              ('направить 0 заявления', 2),
#              ('не_быть с стороны', 2),
#              ('заготовить 0 тонн', 2),
#              ('составить 0 рублей', 2),
#              ('составить 0 процента', 2),
#              ('составить 0 млрд', 2),
#              ('составить 0 миллионов', 2),
#              ('составить согласно данным', 2),
#              ('посеять 0 культуры', 2),
#              ('проводиться 0 мероприятия', 2),
#              ('проводиться 0 раз', 2),
#              ('проводиться 0 день', 2),
#              ('внести 0 представления', 2),
#              ('внести 0 изменения', 2),
#              ('внести 0 поправки', 2),
#              ('собрать 0 детей', 2),
#              ('собрать 0 любителей', 2),
#              ('занять в итоге', 2),
#              ('занять 0 места', 2),
#              ('наградить 0 победители', 2),
#              ('оставить 0 часть', 2),
#              ('устранить 0 нарушения', 2),
#              ('оборудовать 0 места', 2),
#              ('наступить после употребления', 2),
#              ('закрыть 0 дверь', 2),
#              ('разбить 0 стекло', 2),
#              ('разбить 0 стекла', 2),
#              ('обнаружить 0 труп', 2),
#              ('обнаружить 0 тело', 2),
#              ('подвести 0 итоги', 2),
#              ('не_подвести 0 итоги', 2),
#              ('не_огородить 0 забором', 2),
#              ('устанавливаться 0 лица', 2),
#              ('украсть 0 колеса', 2),
#              ('оказать 0 помощь', 2),
#              ('оказать 0 црб', 2),
#              ('поставить 0 диагноз', 2),
#              ('накрыть 0 стол', 2),
#              ('открыть 0 сезон', 2),
#              ('открыть 0 двери', 2),
#              ('открыть 0 счет', 2),
#              ('найти 0 игрушки', 2),
#              ('спасти 0 жизнь', 2),
#              ('установить 0 личность', 2),
#              ('установить 0 лица', 2),
#              ('установить 0 место', 2),
#              ('установить 0 обстоятельства', 2),
#              ('привлечь 0 лица', 2),
#              ('прибыть в п', 2),
#              ('дать 0 сигнал', 2),
#              ('дать 0 возможность', 2),
#              ('дать 0 старт', 2),
#              ('дать 0 разъяснения', 2),
#              ('дать 0 ответ', 2),
#              ('возбудить 0 отделом', 2),
#              ('предусмотреть 0 тыс', 2),
#              ('похитить 0 мотоцикл', 2),
#              ('стоить 0 рублей', 2),
#              ('предпринять 0 меры', 2),
#              ('написать 0 романов', 2),
#              ('написать 0 стихотворение', 2),
#              ('предоставить 0 возможность', 2),
#              ('предоставить 0 магазином', 2),
#              ('изменить 0 номер', 2),
#              ('выявить 0 нарушения', 2),
#              ('выявить 0 факторы', 2),
#              ('выявить 0 победителей', 2),
#              ('увеличить 0 срок', 2),
#              ('запретить 0 курение', 2),
#              ('не_стать 0 жертвой', 2),
#              ('не_стать 0 исключением', 2),
#              ('не_стать 0 лет', 2),
#              ('не_стать 0 победителем', 2),
#              ('не_стать 0 призерами', 2),
#              ('не_стать 0 человеком', 2),
#              ('не_стоить 0 рублей', 2),
#              ('вынести 0 приговор', 2),
#              ('нанести 0 повреждения', 2),
#              ('нанести 0 побои', 2),
#              ('поздравить 0 дам', 2),
#              ('сделать 0 вывод', 2),
#              ('сделать 0 многое', 2),
#              ('сделать 0 шаг', 2),
#              ('сделать 0 шаги', 2),
#              ('сделать 0 фото', 2),
#              ('проходить в регионах', 2),
#              ('выразить 0 отношение', 2),
#              ('выполнить 0 мероприятия', 2),
#              ('выполнить 0 разряд', 2),
#              ('выполнить 0 план', 2),
#              ('завершить 0 расследование', 2),
#              ('завершить 0 работы', 2),
#              ('завершить 0 посев', 2),
#              ('назначить 0 пособие', 2),
#              ('погибнуть в авариях', 2),
#              ('отмечаться 0 праздник', 2),
#              ('подвергать 0 опасности', 2),
#              ('зарегистрировать в эл', 2),
#              ('обучаться 0 техникума', 2),
#              ('обучаться 0 классов', 2),
#              ('обучаться 0 класса', 2),
#              ('обучаться 0 школы', 2),
#              ('обучаться 0 аст', 2),
#              ('отдать 0 годы', 2),
#              ('отдать 0 предпочтение', 2),
#              ('причинить 0 вред', 2),
#              ('произвести 0 ремонт', 2),
#              ('произвести 0 тонн', 2),
#              ('удовлетворить 0 требования', 2),
#              ('возложить 0 цветы', 2),
#              ('уполномочить 0 полиции', 2),
#              ('становиться 0 раз', 2),
#              ('становиться в время', 2),
#              ('вырубить 0 деревьев', 2),
#              ('утвердить 0 план', 2),
#              ('утвердить 0 правила', 2),
#              ('не_закрываться на замок', 2),
#              ('устроить 0 праздник', 2),
#              ('построить 0 дом', 2),
#              ('дойти до рублей', 2),
#              ('не_иметь 0 детей-инвалидов', 2),
#              ('не_иметь 0 образования', 2),
#              ('не_иметь 0 представления', 2),
#              ('не_иметь 0 возможности', 2),
#              ('не_обнаружить 0 труп', 2),
#              ('не_обнаружить 0 тело', 2),
#              ('не_обойтись без спиртного', 2),
#              ('представить 0 район', 2),
#              ('представить 0 работ', 2),
#              ('представить 0 работы', 2),
#              ('отправить 0 человек', 2),
#              ('отправить из района', 2),
#              ('отменить 0 переход', 2),
#              ('не_представить 0 район', 2),
#              ('не_представить 0 работ', 2),
#              ('не_представить 0 работы', 2),
#              ('не_предусмотреть 0 ответственность', 2),
#              ('не_предусмотреть 0 кодексом', 2),
#              ('не_предусмотреть 0 тыс', 2),
#              ('подарить 0 внуков', 2),
#              ('живить 0 лес', 2),
#              ('снизить 0 уровень', 2),
#              ('объявить 0 конкурс', 2),
#              ('желать без ограничений', 2),
#              ('приготовить 0 подарки', 2),
#              ('обеспечить 0 доступ', 2),
#              ('достигнуть 0 рублей', 2),
#              ('помочь 0 словом', 2),
#              ('лишить 0 родителей', 2),
#              ('не_обеспечить 0 оснащение', 2),
#              ('не_обеспечить 0 доступ', 2),
#              ('заключить 0 соглашение', 2),
#              ('заключить 0 договор', 2),
#              ('не_допускаться 0 расторжение', 2),
#              ('заболеть 0 орви', 2),
#              ('остановить 0 автомобиль', 2),
#              ('не_оборудовать 0 места', 2),
#              ('не_оборудовать 0 сигнализацией', 2),
#              ('уплатить 0 пени', 2),
#              ('достаться 0 пирамиде', 2),
#              ('не_организовать 0 мероприятие', 2),
#              ('не_организовать 0 соревнования', 2),
#              ('не_организовать 0 сбор', 2),
#              ('не_найти 0 игрушки', 2),
#              ('убрать 0 культуры', 2),
#              ('не_заниматься 0 организацией', 2),
#              ('уделяться 0 деятельности', 2),
#              ('оценить 0 труд', 2),
#              ('не_дать в обиду', 2),
#              ('превысить в году', 2),
#              ('подать 0 заявление', 2),
#              ('подать 0 заявки', 2),
#              ('подать 0 заявления', 2),
#              ('не_установить 0 личность', 2),
#              ('не_установить 0 лица', 2),
#              ('не_установить 0 место', 2),
#              ('не_установить 0 обстоятельства', 2),
#              ('не_установить 0 срок', 2),
#              ('озвучить 0 цифры', 2),
#              ('не_пользоваться 0 популярностью', 2),
#              ('создать 0 пункты', 2),
#              ('создать 0 условия', 2),
#              ('создать 0 места', 2),
#              ('представлять в числе', 2),
#              ('не_представлять в числе', 2),
#              ('присудить 0 место', 2),
#              ('присудить 0 титул', 2),
#              ('захватить 0 флаг', 2),
#              ('присвоить 0 звание', 2),
#              ('подписать 0 указ', 2),
#              ('подписать 0 приказ', 2),
#              ('вручить 0 удостоверение', 2),
#              ('вручить 0 награды', 2),
#              ('вручить 0 дипломы', 2),
#              ('вручить 0 билеты', 2),
#              ('вручить 0 подарки', 2),
#              ('вручить 0 благодарности', 2),
#              ('вручить 0 диплом', 2),
#              ('вручить 0 медаль', 2),
#              ('вручить 0 документ', 2),
#              ('вручить 0 свидетельства', 2),
#              ('вручить 0 сертификаты', 2),
#              ('вручить 0 грамоты', 2),
#              ('вручить 0 медали', 2),
#              ('завоевать среди девушек', 2),
#              ('обходиться по подсчетам', 2),
#              ('выиграть 0 партии', 2),
#              ('не_занять 0 места', 2),
#              ('превышать по итогам', 2),
#              ('записать 0 ребенка', 2),
#              ('выделить 0 место', 2),
#              ('выделить 0 средства', 2),
#              ('выделить 0 путевок', 2),
#              ('выделить 0 млн', 2),
#              ('выделить 0 тысяч', 2),
#              ('удостоить 0 звания', 2),
#              ('засеять 0 га', 2),
#              ('засеять 0 гектаров', 2),
#              ('учредить 0 орден', 2),
#              ('не_получить 0 плату', 2),
#              ('не_получить 0 субсидии', 2),
#              ('не_получить 0 свидетельства', 2),
#              ('запланировать 0 мероприятия', 2),
#              ('насчитываться 0 человек', 2),
#              ('издать 0 книга', 2),
#              ('дарить в день', 2),
#              ('воспитывать 0 детей', 2),
#              ('воспитать 0 детей', 2),
#              ('не_зарегистрировать в эл', 2),
#              ('уделить 0 внимание', 2),
#              ('затронуть 0 вопросы', 2),
#              ('не_входить в программу', 2),
#              ('не_входить в состав', 2),
#              ('вырастить 0 детей', 2),
#              ('не_собрать 0 детей', 2),
#              ('не_собрать 0 любителей', 2),
#              ('не_назвать 0 имена', 2),
#              ('не_назвать 0 цифры', 2),
#              ('поощрить 0 учеников', 2),
#              ('рассчитать на детей', 2),
#              ('рассчитать на года', 2),
#              ('не_учиться в школах', 2),
#              ('не_учиться 0 класса', 2),
#              ('не_подлежать 0 регистрации', 2),
#              ('не_подлежать 0 призыву', 2),
#              ('разрисовать 0 стены', 2),
#              ('не_разрисовать 0 стены', 2),
#              ('обмолотить 0 хлеба', 2),
#              ('разместить 0 фотографии', 2),
#              ('не_дойти до рублей', 2),
#              ('навести 0 порядок', 2),
#              ('не_сидеть без дела', 2),
#              ('не_сидеть без работы', 2),
#              ('не_становиться 0 раз', 2),
#              ('не_оплачивать 0 счета', 2),
#              ('не_проводиться 0 мероприятия', 2),
#              ('не_проводиться 0 раз', 2),
#              ('не_проводиться 0 день', 2),
#              ('не_решить 0 вопрос', 2),
#              ('приковать 0 внимание', 2),
#              ('отключить 0 отопление', 2),
#              ('не_завершить 0 расследование', 2),
#              ('не_завершить 0 работы', 2),
#              ('не_завершить 0 посев', 2),
#              ('не_приступить к заготовке', 2),
#              ('не_заготовить 0 тонн', 2),
#              ('не_увидеть 0 места', 2),
#              ('случиться в году', 1),
#              ('случиться в начале', 1),
#              ('случиться в п', 1),
#              ('случиться в хозяйстве', 1),
#              ('случиться в г', 1),
#              ('случиться в часов', 1),
#              ('случиться в поселке', 1),
#              ('случиться в месте', 1),
#              ('случиться в доме', 1),
#              ('случиться меньше—в пятницу', 1),
#              ('случиться на километре', 1),
#              ('случиться с утра', 1),
#              ('случиться с жительницей', 1),
#              ('случиться 0 ночью', 1),
#              ('случиться спустя неделю', 1),
#              ('случиться у максима', 1),
#              ('случиться по вине', 1),
#              ('просиять в земле', 1),
#              ('приступить к службе', 1),
#              ('приступить к тушению', 1),
#              ('приступить к работе', 1),
#              ('приступить к разбирательству', 1),
#              ('приступить к работам', 1),
#              ('приступить к обязанностям', 1),
#              ('приступить к погрузке', 1),
#              ('приступить к проектированию', 1),
#              ('приступить к отключению', 1),
#              ('приступить к реализации', 1),
#              ('приступить к уборке', 1),
#              ('приступить к постановке', 1),
#              ('приступить к вручению', 1),
#              ('приступить к разработке', 1),
#              ('приступить к сооружению', 1),
#              ('приступить к рытью', 1),
#              ('приступить к заделке', 1),
#              ('приступить к скашиванию', 1),
#              ('приступить к промывке', 1),
#              ('приступить к посеву', 1),
#              ('приступить к ремонту', 1),
#              ('приступить к выполнению', 1),
#              ('приступить к заготовке', 1),
#              ('приступить к жатве', 1),
#              ('приступить по следам', 1),
#              ('приступить по словам', 1),
#              ('приступить 0 миром', 1),
#              ('приступить 0 осенью', 1),
#              ('приступить в раз', 1),
#              ('приступить в районе', 1),
#              ('приступить в конце', 1),
#              ('приступить в больнице', 1),
#              ('приступить в году', 1),
#              ('приступить в спк', 1),
#              ('приступить в период', 1),
#              ('приступить в молодости', 1),
#              ('приступить в июле', 1),
#              ('приступить в начале', 1),
#              ('приступить в феврале', 1),
#              ('приступить с понедельника', 1),
#              ('приступить с появлением', 1),
#              ('приступить района—в понедельник', 1),
#              ('приступить на станции', 1),
#              ('приступить на неделе', 1),
#              ('приступить на днях', 1),
#              ('приступить после уборки', 1),
#              ('приступить из сельхозпредприятий', 1),
#              ('рассказать в интервью', 1),
#              ('рассказать в огибдд', 1),
#              ('рассказать в отделе', 1),
#              ('рассказать в помещении', 1),
#              ('рассказать в мо', 1),
#              ('рассказать в канун', 1),
#              ('рассказать в номере', 1),
#              ('рассказать в понедельник', 1),
#              ('рассказать в деревне', 1),
#              ('рассказать в очерке', 1),
#              ('рассказать в онд', 1),
#              ('рассказать в докладе', 1),
#              ('рассказать в форме', 1),
#              ('рассказать в беседе', 1),
#              ('рассказать о мерах', 1),
#              ('рассказать о уловках', 1),
#              ('рассказать о работах', 1),
#              ('рассказать о религии', 1),
#              ('рассказать о истории', 1),
#              ('рассказать о судьбе', 1),
#              ('рассказать о киноактёрах', 1),
#              ('рассказать о аспектах', 1),
#              ('рассказать о ситуации', 1),
#              ('рассказать о службе', 1),
#              ('рассказать о итогах', 1),
#              ('рассказать о жизни', 1),
#              ('рассказать о коллегах', 1),
#              ('рассказать о аспекте', 1),
#              ('рассказать о играх', 1),
#              ('рассказать о молодости', 1),
#              ('рассказать о школьнике', 1),
#              ('рассказать о конституции', 1),
#              ('рассказать о власти', 1),
#              ('рассказать о флоре', 1),
#              ('рассказать о куклах', 1),
#              ('рассказать о а', 1),
#              ('рассказать о педагоге', 1),
#              ('рассказать о специфике', 1),
#              ('рассказать о работе', 1),
#              ('рассказать о студентках', 1),
#              ('рассказать о творчестве', 1),
#              ('рассказать о хлопотах', 1),
#              ('рассказать о услугах', 1),
#              ('рассказать о смене', 1),
#              ('рассказать о изменениях', 1),
#              ('рассказать о выставке', 1),
#              ('рассказать о любви', 1),
#              ('рассказать о событии', 1),
#              ('рассказать о успехах', 1),
#              ('рассказать о фестивале', 1),
#              ('рассказать о программе', 1),
#              ('рассказать о деятельности', 1),
#              ('рассказать о церемонии', 1),
#              ('рассказать о перспективах', 1),
#              ('рассказать о волейболе', 1),
#              ('рассказать о результатах', 1),
#              ('рассказать о канонах', 1),
#              ('рассказать о наказаниях', 1),
#              ('рассказать о конструировании', 1),
#              ('рассказать о особенностях', 1),
#              ('рассказать о событиях', 1),
#              ('рассказать о правах', 1),
#              ('рассказать о городе', 1),
#              ('рассказать о ходу', 1),
#              ('рассказать о реализации', 1),
#              ('рассказать о планах', 1),
#              ('рассказать о целях', 1),
#              ('рассказать о буднях', 1),
#              ('рассказать о преимуществах', 1),
#              ('рассказать о методе', 1),
#              ('рассказать о предприятиях', 1),
#              ('рассказать о состоянии', 1),
#              ('рассказать о отдыхе', 1),
#              ('рассказать о порядке', 1),
#              ('рассказать о человеке', 1),
#              ('рассказать 0 соседу', 1),
#              ('рассказать 0 участникам', 1),
#              ('рассказать 0 считалки', 1),
#              ('рассказать 0 воспитанникам', 1),
#              ('рассказать 0 гостям', 1),
#              ('рассказать 0 а', 1),
#              ('рассказать 0 детям', 1),
#              ('рассказать 0 ребятам', 1),
#              ('рассказать 0 школьникам', 1),
#              ('рассказать 0 читателю', 1),
#              ('рассказать 0 руководителя', 1),
#              ('рассказать 0 читателям', 1),
#              ('рассказать 0 многое', 1),
#              ('рассказать 0 руководителей', 1),
#              ('рассказать 0 заведующего', 1),
#              ('рассказать 0 студентам', 1),
#              ('рассказать 0 корреспонденту', 1),
#              ('рассказать 0 историю', 1),
#              ('рассказать про обряды', 1),
#              ('рассказать про семьи', 1),
#              ('рассказать по очереди', 1),
#              ('рассказать за беседой', 1),
#              ('рассказать за годы', 1),
#              ('рассказать на уроке', 1),
#              ('рассказать на экскурсии', 1),
#              ('рассказать на планерке', 1),
#              ('рассказать на встрече', 1),
#              ('рассказать на раз', 1),
#              ('рассказать с помощью презентации', 1),
#              ('рассказать с сцены', 1),
#              ('рассказать в ходе линии', 1),
#              ('стоять в углу', 1),
#              ('стоять в дворе', 1),
#              ('стоять в с', 1),
#              ('стоять в время', 1),
#              ('стоять в парниках', 1),
#              ('стоять в очереди', 1),
#              ('стоять в республике', 1),
#              ('стоять в районе', 1),
#              ('стоять в улицу', 1),
#              ('стоять в форме', 1),
#              ('стоять в ряд', 1),
#              ('стоять в зале', 1),
#              ('стоять в спальне', 1),
#              ('стоять у дома', 1),
#              ('стоять у истоков', 1),
#              ('стоять у станков', 1),
#              ('стоять на веранде', 1),
#              ('стоять на улице', 1),
#              ('стоять на морозе', 1),
#              ('стоять на день', 1),
#              ('стоять на страже', 1),
#              ('стоять на столе', 1),
#              ('стоять на неделе', 1),
#              ('стоять на повестке', 1),
#              ('стоять на месте', 1),
#              ('стоять возле дома', 1),
#              ('стоять под слоем', 1),
#              ('стоять порядок тысяч', 1),
#              ('стоять 0 колом', 1),
#              ('стоять 0 год', 1),
#              ('стоять 0 сорняками', 1),
#              ('стоять без дела', 1),
#              ('стоять по стойке', 1),
#              ('получать 0 образование', 1),
#              ('получать 0 молока', 1),
#              ('получать 0 ранения', 1),
#              ('получать 0 травмы', 1),
#              ('получать 0 травму', 1),
#              ('получать 0 пенсию', 1),
#              ('получать 0 исцеление', 1),
#              ('получать 0 компенсацию', 1),
#              ('получать 0 машинку', 1),
#              ('получать 0 набор', 1),
#              ('получать 0 фен', 1),
#              ('получать 0 диплом', 1),
#              ('получать 0 родителями', 1),
#              ('получать 0 подарков', 1),
#              ('получать 0 количество', 1),
#              ('получать 0 плату', 1),
#              ('получать 0 функции', 1),
#              ('получать 0 урожайность', 1),
#              ('получать 0 стипендию', 1),
#              ('получать 0 номер', 1),
#              ('получать 0 стресс', 1),
#              ('получать 0 статус', 1),
#              ('получать 0 подарки', 1),
#              ('получать 0 пособие', 1),
#              ('получать 0 поздравления', 1),
#              ('получать 0 зерна', 1),
#              ('получать 0 урожаи', 1),
#              ('получать 0 четверки', 1),
#              ('получать 0 признание', 1),
#              ('получать 0 выплату', 1),
#              ('получать 0 капитал', 1),
#              ('получать 0 мед', 1),
#              ('получать 0 письма', 1),
#              ('получать 0 зарплату', 1),
#              ('получать 0 поддержку', 1),
#              ('получать 0 субсидию', 1),
#              ('получать 0 информацию', 1),
#              ('получать 0 сертификат', 1),
#              ('получать 0 приз', 1),
#              ('получать 0 порцию', 1),
#              ('получать 0 сумму', 1),
#              ('получать 0 урожай', 1),
#              ('получать 0 средства', 1),
#              ('получать 0 карточку', 1),
#              ('получать 0 возможность', 1),
#              ('получать 0 нагрузки', 1),
#              ('получать 0 правило', 1),
#              ('получать 0 квитанции', 1),
#              ('получать 0 неделю', 1),
#              ('получать 0 звание', 1),
#              ('получать 0 миллионов', 1),
#              ('получать 0 надои', 1),
#              ('получать 0 рублей', 1),
#              ('получать 0 помощь', 1),
#              ('получать 0 участки', 1),
#              ('получать 0 распространение', 1),
#              ('получать в время', 1),
#              ('получать в субботу', 1),
#              ('получать в дтп', 1),
#              ('получать в подарок', 1),
#              ('получать в дни', 1),
#              ('получать в году', 1),
#              ('получать в результате', 1),
#              ('получать в канун', 1),
#              ('получать в среднем', 1),
#              ('получать в награду', 1),
#              ('получать в конце', 1),
#              ('получать в режиме', 1),
#              ('получать в годы', 1),
#              ('получать в районе', 1),
#              ('получать в половине', 1),
#              ('получать по вторникам', 1),
#              ('получать по линии', 1),
#              ('получать по уходу', 1),
#              ('получать по центнеров', 1),
#              ('получать по месяцев', 1),
#              ('получать по поросенка', 1),
#              ('получать после молитвы', 1),
#              ('получать после обучения', 1),
#              ('получать из с', 1),
#              ('получать из газет', 1),
#              ('получать из точки', 1),
#              ('получать из бюджета', 1),
#              ('получать на трудодни', 1),
#              ('получать на развитие', 1),
#              ('получать на месте', 1),
#              ('получать за рублей', 1),
#              ('получать за трудодень', 1),
#              ('получать за детей', 1),
#              ('получать за опорос', 1),
#              ('получать в соответствии с указанием', 1),
#              ('получать благодаря способностям', 1),
#              ('получать благодаря соблюдению', 1),
#              ('получать с гектара', 1),
#              ('получать с едой', 1),
#              ('получать от учеников', 1),
#              ('получать от книги', 1),
#              ('получать от члена', 1),
#              ('получать от свиноматки', 1),
#              ('получать между конкурсами', 1),
#              ('получать до центнеров', 1),
#              ('получать вместо бюллетеня', 1),
#              ('получать в течение лет', 1),
#              ('получать в виде конверта', 1),
#              ('быть к счастью', 1),
#              ('быть к сожалению', 1),
#              ('быть к примеру', 1),
#              ('быть у происшествия', 1),
#              ('быть у школы', 1),
#              ('быть у школьников', 1),
#              ('быть у валентины', 1),
#              ('быть у представителей', 1),
#              ('быть у детей', 1),
#              ('быть у читателей', 1),
#              ('быть у подписчиков', 1),
#              ('быть у человека', 1),
#              ('быть у жителей', 1),
#              ('быть у народа', 1),
#              ('быть у человек', 1),
#              ('быть у бухгалтеров', 1),
#              ('быть у полиции', 1),
#              ('быть у праздника', 1),
#              ('быть у советчан', 1),
#              ('быть у ребятишек', 1),
#              ('быть у членов', 1),
#              ('быть у веры', 1),
#              ('быть у продуктов', 1),
#              ('быть у участников', 1),
#              ('быть у ларисы', 1),
#              ('быть у ходьбы', 1),
#              ('быть у ребят', 1),
#              ('быть у любы', 1),
#              ('быть у супругов', 1),
#              ('быть у сети', 1),
#              ('быть у булыгиных', 1),
#              ('быть у участника', 1),
#              ('быть у мамы', 1),
#              ('быть у подразделения', 1),
#              ('быть у профессии', 1),
#              ('быть у учреждения', 1),
#              ('быть вблизи берега', 1),
#              ('быть 0 часть', 1),
#              ('быть 0 проблема', 1),
#              ('быть 0 иван', 1),
#              ('быть 0 школе', 1),
#              ('быть 0 сыну', 1),
#              ('быть 0 года', 1),
#              ('быть 0 словом', 1),
#              ('быть 0 люду', 1),
#              ('быть 0 валентине', 1),
#              ('быть 0 событие', 1),
#              ('быть 0 раз', 1),
#              ('быть 0 потребителям', 1),
#              ('быть 0 слова', 1),
#              ('быть 0 зимой', 1),
#              ('быть 0 россиянам', 1),
#              ('быть на пути', 1),
#              ('быть на груди', 1),
#              ('быть на рублей', 1),
#              ('быть на страницах', 1),
#              ('быть на момент', 1),
#              ('быть на плане', 1),
#              ('быть на земле', 1),
#              ('быть на выставке', 1),
#              ('быть на волге', 1),
#              ('быть на мероприятии', 1),
#              ('быть на площадках', 1),
#              ('быть на сайте', 1),
#              ('быть в год', 1),
#              ('быть в погашении', 1),
#              ('быть в доме', 1),
#              ('быть в гараже', 1),
#              ('быть в квартире', 1),
#              ('быть в школе', 1),
#              ('быть в случаях', 1),
#              ('быть в центре', 1),
#              ('быть в поселке', 1),
#              ('быть в россии', 1),
#              ('быть в году', 1),
#              ('быть в странах', 1),
#              ('быть в стране', 1),
#              ('быть в семье', 1),
#              ('быть в детстве', 1),
#              ('быть в школах', 1),
#              ('быть в дни', 1),
#              ('быть в время', 1),
#              ('быть в районе', 1),
#              ('быть в канун', 1),
#              ('быть в комнате', 1),
#              ('быть в времена', 1),
#              ('быть в жизни', 1),
#              ('быть в законодательстве', 1),
#              ('быть в храме', 1),
#              ('быть в поселении', 1),
#              ('быть в пользу', 1),
#              ('быть в больнице', 1),
#              ('быть в хозяйстве', 1),
#              ('быть в записи', 1),
#              ('быть в церкви', 1),
#              ('быть в использовании', 1),
#              ('быть в деревнях', 1),
#              ('быть в деревне', 1),
#              ('быть в системе', 1),
#              ('быть с раза', 1),
#              ('быть с километра', 1),
#              ('быть с детства', 1),
#              ('быть для целей', 1),
#              ('быть при выборе', 1),
#              ('быть при поступлении', 1),
#              ('быть среди выпускников', 1),
#              ('быть среди родственников', 1),
#              ('быть по услугам', 1),
#              ('быть по словам', 1),
#              ('быть по заказу', 1),
#              ('быть помимо взрослых', 1),
#              ('быть помимо вкладов', 1),
#              ('быть помимо плюсов', 1),
#              ('быть за лет', 1),
#              ('быть за часа', 1),
#              ('быть за детьми', 1),
#              ('быть вместо сигарет', 1),
#              ('быть до финиша', 1),
#              ('быть до воды', 1),
#              ('быть до игры', 1),
#              ('быть до пор', 1),
#              ('быть из родника', 1),
#              ('быть возле поворота', 1),
#              ('родиться в году', 1),
#              ('родиться в селе', 1),
#              ('родиться в семье', 1),
#              ('родиться в рубашке', 1),
#              ('родиться в д', 1),
#              ('родиться в деревне', 1),
#              ('родиться в п', 1),
#              ('родиться в эл', 1),
#              ('родиться в день', 1),
#              ('родиться в больнице', 1),
#              ('родиться в районе', 1),
#              ('родиться в годы', 1),
#              ('родиться в г', 1),
#              ('родиться в с', 1),
#              ('родиться в деревеньке', 1),
#              ('родиться в городе', 1),
#              ('родиться в январе', 1),
#              ('родиться в время', 1),
#              ('родиться с весом', 1),
#              ('родиться с собеседником', 1),
#              ('родиться на неделе', 1),
#              ('родиться на тему', 1),
#              ('родиться 0 женщиной', 1),
#              ('родиться 0 мальчиком', 1),
#              ('родиться 0 ребенка', 1),
#              ('родиться 0 ребенком', 1),
#              ('родиться 0 матерью', 1),
#              ('родиться 0 зимой', 1),
#              ('родиться 0 года', 1),
#              ('родиться за период', 1),
#              ('родиться за квартал', 1),
#              ('родиться за год', 1),
#              ('родиться за месяцев', 1),
#              ('родиться из деревни', 1),
#              ('родиться у пары', 1),
#              ('родиться у представителей', 1),
#              ('родиться у ефима', 1),
#              ('родиться через года', 1),
#              ('родиться согласно данным', 1),
#              ('родиться о собеседнике', 1),
#              ('родиться после сына', 1),
#              ('переехать в году', 1),
#              ('переехать в г', 1),
#              ('переехать в здание', 1),
#              ('переехать в жильё', 1),
#              ('переехать в северное', 1),
#              ('переехать в село', 1),
#              ('переехать в михайловку', 1),
#              ('переехать в пос', 1),
#              ('переехать в тц', 1),
#              ('переехать в зал', 1),
#              ('переехать в помещение', 1),
#              ('переехать из домика', 1),
#              ('переехать на родину', 1),
#              ('получить 0 образование', 1),
#              ('получить 0 информацию', 1),
#              ('получить 0 ушиб', 1),
#              ('получить 0 аванс', 1),
#              ('получить 0 повреждения', 1),
#              ('получить 0 ранения', 1),
#              ('получить 0 ожоги', 1),
#              ('получить 0 травму', 1),
#              ('получить 0 травмы', 1),
#              ('получить 0 сообщение', 1),
#              ('получить 0 ссадины', 1),
#              ('получить 0 повреждение', 1),
#              ('получить 0 плату', 1),
#              ('получить 0 переохлаждение', 1),
#              ('получить 0 перелом', 1),
#              ('получить 0 деньги', 1),
#              ('получить 0 ожог', 1),
#              ('получить 0 вечером', 1),
#              ('получить 0 отравление', 1),
#              ('получить 0 приглашения', 1),
#              ('получить 0 акты', 1),
#              ('получить 0 информация', 1),
#              ('получить 0 специальность', 1),
#              ('получить 0 профессию', 1),
#              ('получить 0 набор', 1),
#              ('получить 0 видеорегистратор', 1),
#              ('получить 0 фотокамеру—р', 1),
#              ('получить 0 грант', 1),
#              ('получить 0 поддержку', 1),
#              ('получить 0 аттестат', 1),
#              ('получить 0 диплом', 1),
#              ('получить 0 книги', 1),
#              ('получить 0 награды—знаки', 1),
#              ('получить 0 знаки', 1),
#              ('получить 0 благодарности', 1),
#              ('получить 0 дипломы', 1),
#              ('получить 0 сумму', 1),
#              ('получить 0 свидетельство', 1),
#              ('получить 0 облучение', 1),
#              ('получить 0 пользу', 1),
#              ('получить 0 лицензию', 1),
#              ('получить 0 одобрение', 1),
#              ('получить 0 группу', 1),
#              ('получить 0 ранение', 1),
#              ('получить 0 лечение', 1),
#              ('получить 0 подарки', 1),
#              ('получить 0 принадлежности', 1),
#              ('получить 0 средства', 1),
#              ('получить 0 оценку', 1),
#              ('получить 0 консультацию', 1),
#              ('получить 0 госуслугу', 1),
#              ('получить 0 кубок', 1),
#              ('получить 0 ответы', 1),
#              ('получить 0 награды', 1),
#              ('получить 0 выплату', 1),
#              ('получить 0 воспаление', 1),
#              ('получить 0 уведомлений', 1),
#              ('получить 0 разряд', 1),
#              ('получить 0 приз', 1),
#              ('получить 0 повестки', 1),
#              ('получить 0 отсрочки', 1),
#              ('получить 0 тонн', 1),
#              ('получить 0 толчок', 1),
#              ('получить 0 аттестаты', 1),
#              ('получить 0 справку', 1),
#              ('получить 0 похоронку', 1),
#              ('получить 0 извещение', 1),
#              ('получить 0 известность', 1),
#              ('получить 0 медаль', 1),
#              ('получить 0 советы', 1),
#              ('получить 0 удостоверение', 1),
#              ('получить 0 количество', 1),
#              ('получить 0 сертификаты', 1),
#              ('получить 0 субсидии', 1),
#              ('получить 0 приглашение', 1),
#              ('получить 0 задание', 1),
#              ('получить 0 название', 1),
#              ('получить 0 сертификат', 1),
#              ('получить 0 возможность', 1),
#              ('получить 0 квартиры', 1),
#              ('получить 0 денег', 1),
#              ('получить 0 миллион', 1),
#              ('получить 0 ячменя', 1),
#              ('получить 0 путевок', 1),
#              ('получить 0 информации', 1),
#              ('получить 0 путевки', 1),
#              ('получить 0 наставления', 1),
#              ('получить 0 наименование', 1),
#              ('получить 0 опыт', 1),
#              ('получить 0 титул', 1),
#              ('получить 0 билеты', 1),
#              ('получить 0 права', 1),
#              ('получить 0 категорию', 1),
#              ('получить 0 путевку', 1),
#              ('получить 0 мальчиков', 1),
#              ('получить 0 квартиру', 1),
#              ('получить 0 сувениры', 1),
#              ('получить 0 ответ', 1),
#              ('получить 0 вещи', 1),
#              ('получить 0 пенал', 1),
#              ('получить 0 машинки', 1),
#              ('получить 0 книжки', 1),
#              ('получить 0 наград', 1),
#              ('получить 0 статус', 1),
#              ('получить 0 призы', 1),
#              ('получить 0 грамоты', 1),
#              ('получить 0 отклики', 1),
#              ('получить 0 удовольствие', 1),
#              ('получить 0 анкету', 1),
#              ('получить 0 млн', 1),
#              ('получить 0 мяса', 1),
#              ('получить 0 пенсию', 1),
#              ('получить 0 награду', 1),
#              ('получить 0 распространение', 1),
#              ('получить 0 место', 1),
#              ('получить 0 шарфики', 1),
#              ('получить 0 грамоту', 1),
#              ('получить 0 футболки', 1),
#              ('получить 0 право', 1),
#              ('получить 0 направление', 1),
#              ('получить 0 автомобили', 1),
#              ('получить 0 подарок', 1),
#              ('получить 0 документы', 1),
#              ('получить 0 лет', 1),
#              ('получить 0 консультации', 1),
#              ('получить 0 трактористы-машинисты', 1),
#              ('получить 0 звезду', 1),
#              ('получить 0 заключение', 1),
#              ('получить 0 субсидию', 1),
#              ('получить 0 паспорт', 1),
#              ('получить 0 телефон', 1),
#              ('получить 0 уведомления', 1),
#              ('получить 0 смс-сообщение', 1),
#              ('получить 0 премию', 1),
#              ('получить 0 благодарность', 1),
#              ('получить 0 лист', 1),
#              ('получить 0 услуги', 1),
#              ('получить 0 килограммов', 1),
#              ('получить 0 обморожения', 1),
#              ('получить 0 вознаграждение', 1),
#              ('получить 0 автомобиль', 1),
#              ('получить 0 счет', 1),
#              ('получить 0 килограмма', 1),
#              ('получить 0 штраф', 1),
#              ('получить 0 массу', 1),
#              ('получить 0 разъяснения', 1),
#              ('получить 0 карты', 1),
#              ('получить 0 корочки', 1),
#              ('получить 0 приза', 1),
#              ('получить в результате', 1),
#              ('получить в дтп', 1),
#              ('получить в академии', 1),
#              ('получить в подарок', 1),
#              ('получить в школе', 1),
#              ('получить в день', 1),
#              ('получить в районе', 1),
#              ('получить в деле', 1),
#              ('получить в донецке', 1),
#              ('получить в приезд', 1),
#              ('получить в отделе', 1),
#              ('получить в году', 1),
#              ('получить в целом', 1),
#              ('получить в случае', 1),
#              ('получить в учреждении', 1),
#              ('получить в конце', 1),
#              ('получить в семья', 1),
#              ('получить в номинации', 1),
#              ('получить в награду', 1),
#              ('получить в категории', 1),
#              ('получить в танце', 1),
#              ('получить в уровни', 1),
#              ('получить в феврале', 1),
#              ('получить в честь', 1),
#              ('получить в колониях', 1),
#              ('получить в пятницу', 1),
#              ('получить в мае', 1),
#              ('получить в квитанции', 1),
#              ('получить в виде', 1),
#              ('получить в год', 1),
#              ('получить в гку', 1),
#              ('получить в итоге', 1),
#              ('получить на телефон', 1),
#              ('получить на работе', 1),
#              ('получить на стройке', 1),
#              ('получить на линейках', 1),
#              ('получить на раз', 1),
#              ('получить на форуме', 1),
#              ('получить на пожарах', 1),
#              ('получить на комиссию', 1),
#              ('получить на конференции', 1),
#              ('получить на основании', 1),
#              ('получить на елку', 1),
#              ('получить на день', 1),
#              ('получить на кэг', 1),
#              ('получить на производстве', 1),
#              ('получить на срок', 1),
#              ('получить на днях', 1),
#              ('получить на исполнение', 1),
#              ('получить по неосторожности', 1),
#              ('получить по телефону', 1),
#              ('получить по адресу', 1),
#              ('получить по почте', 1),
#              ('получить по информации', 1),
#              ('получить по району', 1),
#              ('получить по торту', 1),
#              ('получить по договору', 1),
#              ('получить по количеству', 1),
#              ('получить по данным', 1),
#              ('получить по традиции', 1),
#              ('получить по состоянию', 1),
#              ('получить по телят', 1),
#              ('получить в время работы', 1),
#              ('получить в ходе драки', 1),
#              ('получить в ходе беседы', 1),
#              ('получить при растопке', 1),
#              ('получить за время', 1),
#              ('получить за год', 1),
#              ('получить за пределами', 1),
#              ('получить за работу', 1),
#              ('получить за учебу', 1),
#              ('получить за участие', 1),
#              ('получить из числа', 1),
#              ('получить из района', 1),
#              ('получить из рук', 1),
#              ('получить из них—жители', 1),
#              ('получить из возможность', 1),
#              ('получить из уст', 1),
#              ('получить от настоятеля', 1),
#              ('получить от района', 1),
#              ('получить от родителей', 1),
#              ('получить от начальника', 1),
#              ('получить от мониторов', 1),
#              ('получить от хитов', 1),
#              ('получить от фабрики', 1),
#              ('получить от коров', 1),
#              ('получить от ооо', 1),
#              ('получить от руководителя', 1),
#              ('получить от родных', 1),
#              ('получить от газеты', 1),
#              ('получить в качестве награды', 1),
#              ('получить через год', 1),
#              ('получить с склада', 1),
#              ('получить согласно информации', 1),
#              ('получить в течение дней', 1),
#              ('получить порядок кг', 1),
#              ('получить по сравнению с годом', 1),
#              ('получить после окончания', 1),
#              ('получить благодаря тренировкам', 1),
#              ('получить накануне даты', 1),
#              ('получить к сожалению', 1),
#              ('получить к примеру', 1),
#              ('получить в соответствии с законом', 1),
#              ('получить у специалиста', 1),
#              ('учиться в колледже', 1),
#              ('учиться в семинарии', 1),
#              ('учиться в гпту', 1),
#              ('учиться в школе', 1),
#              ('учиться в сош', 1),
#              ('учиться в школах', 1),
#              ('учиться в училище', 1),
#              ('учиться в районе', 1),
#              ('учиться в группе', 1),
#              ('учиться в школе-интернате', 1),
#              ('учиться в институт', 1),
#              ('учиться в классе', 1),
#              ('учиться в году', 1),
#              ('учиться в школу', 1),
#              ('учиться в семинарию', 1),
#              ('учиться в техникуме', 1),
#              ('учиться в начале', 1),
#              ('учиться в пту', 1),
#              ('учиться в пединститут', 1),
#              ('учиться по специальности', 1),
#              ('учиться по программе', 1),
#              ('учиться с года', 1),
#              ('учиться 0 школы-интерната', 1),
#              ('учиться 0 общению', 1),
#              ('учиться 0 дня', 1),
#              ('учиться 0 участие', 1),
#              ('учиться 0 неделю', 1),
#              ('учиться 0 родители', 1),
#              ('учиться 0 пример', 1),
#              ('учиться 0 парнем', 1),
#              ('учиться 0 мастерству', 1),
#              ('учиться 0 многому', 1),
#              ('учиться 0 специальности', 1),
#              ('учиться 0 года', 1),
#              ('учиться 0 ссш', 1),
#              ('учиться к примеру', 1),
#              ('учиться за неделю', 1),
#              ('учиться на пятерки', 1),
#              ('учиться на курсе', 1),
#              ('учиться на ветеринара', 1),
#              ('учиться на занятиях', 1),
#              ('учиться на отделение', 1),
#              ('учиться на повара', 1),
#              ('учиться на факультетах', 1),
#              ('учиться вместо лет', 1),
#              ('приехать в году', 1),
#              ('приехать в йошкар-олу', 1),
#              ('приехать в гости', 1),
#              ('приехать в январе', 1),
#              ('приехать в день', 1),
#              ('приехать в часов', 1),
#              ('приехать в командировку', 1),
#              ('приехать в кремль', 1),
#              ('приехать в годы', 1),
#              ('приехать в рамках', 1),
#              ('приехать в музей', 1),
#              ('приехать в лагерь', 1),
#              ('приехать в поселок', 1),
#              ('приехать в дворец', 1),
#              ('приехать в деревню', 1),
#              ('приехать в п', 1),
#              ('приехать в санчурск', 1),
#              ('приехать в аст', 1),
#              ('приехать в готовности', 1),
#              ('приехать в раз', 1),
#              ('приехать в редакцию', 1),
#              ('приехать в числе', 1),
#              ('приехать на рыбалку', 1),
#              ('приехать на пруд', 1),
#              ('приехать на праздник', 1),
#              ('приехать на операцию', 1),
#              ('приехать на мероприятие', 1),
#              ('приехать на место', 1),
#              ('приехать на встречу', 1),
#              ('приехать на открытие', 1),
#              ('приехать на турнир', 1),
#              ('приехать на лыжню', 1),
#              ('приехать на площадь', 1),
#              ('приехать на форум', 1),
#              ('приехать на каникулы', 1),
#              ('приехать на награждение', 1),
#              ('приехать по версии', 1),
#              ('приехать по адресу', 1),
#              ('приехать по традиции', 1),
#              ('приехать через время', 1),
#              ('приехать около часов', 1),
#              ('приехать около участников', 1),
#              ('приехать из села', 1),
#              ('приехать из г', 1),
#              ('приехать из москвы', 1),
#              ('приехать из башкортостана', 1),
#              ('приехать из торъяла', 1),
#              ('приехать из леса', 1),
#              ('приехать за семьями', 1),
#              ('приехать за ребятами', 1),
# ...
#              ('не_омрачить 0 случаем', 1),
#              ('не_омрачить 0 воскресенье', 1),
#              ('не_омрачить 0 неделя', 1),
#              ('не_омрачить 0 происшествием', 1),
#              ('не_омрачить 0 начало', 1),
#              ('не_омрачить 0 ростом', 1),
#              ('орошать 0 пастбища', 1),
#              ('полоскать 0 белье', 1),
#              ('охлаждать 0 молоко', 1),
#              ('райпо—принимать в середине', 1),
#              ('райпо—принимать 0 гостей', 1),
#              ('парковаться возле здания', 1),
#              ('спускаться к ящику', 1),
#              ('спускаться к воде', 1),
#              ('спускаться в ожидании', 1),
#              ('продлить 0 режим', 1),
#              ('продлить в раз', 1),
#              ('наращивать с годом', 1),
#              ('наращивать 0 мощность', 1),
#              ('наращивать 0 поголовье', 1),
#              ('заселять 0 этаж', 1),
#              ('ютиться 0 месяцев', 1),
#              ('ютиться в помещениях', 1),
#              ('ютиться в комнате', 1),
#              ('страховать 0 ответственность', 1),
#              ('не_применяться 0 санкции', 1),
#              ('не_применяться 0 индексация', 1),
#              ('не_применяться 0 комплексы', 1),
#              ('не_применяться 0 знак', 1),
#              ('не_применяться 0 закон', 1),
#              ('не_применяться к такси', 1),
#              ('не_сложиться у жителя', 1),
#              ('не_сложиться у большинства', 1),
#              ('не_сложиться у женщины', 1),
#              ('не_сложиться у портних', 1),
#              ('не_сложиться у россиян', 1),
#              ('прогреваться после подачи', 1),
#              ('не_накопить 0 долгов', 1),
#              ('настроиться на отдых', 1),
#              ('настроиться после будней', 1),
#              ('подпортить 0 настроение', 1),
#              ('спровоцировать 0 аварию', 1),
#              ('переоборудовать 0 кафе', 1),
#              ('переоборудовать 0 часть', 1),
#              ('переоборудовать под магазин', 1),
#              ('переоборудовать под забор', 1),
#              ('не_передать 0 информацию', 1),
#              ('перекрывать 0 должникам', 1),
#              ('перекрывать 0 канализацию', 1),
#              ('реконструировать 0 крыльцо', 1),
#              ('отследить 0 события', 1),
#              ('ориентироваться в действительности', 1),
#              ('ориентироваться в вопросах', 1),
#              ('заглядывать в редакцию', 1),
#              ('умалчивать о методах', 1),
#              ('истекать в году', 1),
#              ('истекать в день', 1),
#              ('скапливаться у контейнеров', 1),
#              ('скапливаться в период', 1),
#              ('отрицать 0 нормы', 1),
#              ('не_радовать 0 теплом', 1),
#              ('управляемый 0 евгением', 1),
#              ('предать 0 делу', 1),
#              ('подтверждаться 0 раскопками', 1),
#              ('обволакивать 0 небо', 1),
#              ('лить 0 часами', 1),
#              ('не_прорасти без влаги', 1),
#              ('квасить 0 капусту', 1),
#              ('заквасить 0 овощей', 1),
#              ('промыть 0 раствором', 1),
#              ('очиститься от запаха', 1),
#              ('ополоснуть 0 раз', 1),
#              ('ополоснуть 0 водой', 1),
#              ('обитать в водах', 1),
#              ('обитать в прудах', 1),
#              ('не_поехать на рыбалку', 1),
#              ('не_посмотреть на барометр', 1),
#              ('выманить в прогал', 1),
#              ('выманить 0 рыбу', 1),
#              ('выманить с помощью червя', 1),
#              ('констатировать с огорчением', 1),
#              ('не_претерпевать за полугодие', 1),
#              ('не_претерпевать 0 изменений', 1),
#              ('мыкаться из угла', 1),
#              ('мыкаться в угол', 1),
#              ('пробивать 0 жилье', 1),
#              ('пробивать 0 путь', 1),
#              ('пробивать через лапы', 1),
#              ('пробивать по бурелому', 1),
#              ('разрешаться в период', 1),
#              ('разрешаться в прокуратуру', 1),
#              ('разрешаться 0 охота', 1),
#              ('охотиться на зайцев', 1),
#              ('не_парализовать 0 работу', 1),
#              ('полуразвалиться с пандусами', 1),
#              ('позагорать на пляже', 1),
#              ('демонтировать в день', 1),
#              ('демонтировать при помощи автокрана', 1),
#              ('демонтировать 0 грибки', 1),
#              ('поплескаться в воде', 1),
#              ('пожинать при сдаче', 1),
#              ('пожинать 0 лавры', 1),
#              ('пожинать 0 правило', 1),
#              ('окупать в годы', 1),
#              ('окупать 0 затраты', 1),
#              ('засевать 0 поля', 1),
#              ('засевать 0 культурами', 1),
#              ('устремить в будущее', 1),
#              ('разложить по стопкам', 1),
#              ('разложить 0 объекты', 1),
#              ('предназначаться 0 часть', 1),
#              ('предназначаться району—на ликвидацию', 1),
#              ('достраивать 0 газопровод', 1),
#              ('достраивать за счет спецнадбавки', 1),
#              ('пересматриваться 0 графики', 1),
#              ('пересматриваться с учетом', 1),
#              ('лиц—спрашивать на совещании', 1),
#              ('постучать в дверь', 1),
#              ('одетый в тельняшку', 1),
#              ('склоняться к переходу', 1),
#              ('не_затеряться на фоне', 1),
#              ('важная—вступить в силу', 1),
#              ('вращать 0 барабан', 1),
#              ('наводиться по словам', 1),
#              ('наводиться 0 силами', 1),
#              ('наводиться 0 порядок', 1),
#              ('не_возводить 0 дома', 1),
#              ('не_возводить 0 храм', 1),
#              ('не_возводить 0 миром', 1),
#              ('не_возводить 0 домов', 1),
#              ('не_возводить 0 лет', 1),
#              ('кидать в воду', 1),
#              ('кидать 0 приманку', 1),
#              ('сдерживать 0 развитие', 1),
#              ('проявляться в году', 1),
#              ('не_обращать 0 внимания', 1),
#              ('перепрыгивать через бревно', 1),
#              ('нависать в месте', 1),
#              ('нависать над тропинкой', 1),
#              ('рухнуть 0 час', 1),
#              ('излагать с выгодой', 1),
#              ('излагать для нации', 1),
#              ('не_слабеть 0 памяти', 1),
#              ('задаться 0 вопросами', 1),
#              ('разровнять 0 грунт', 1),
#              ('уберечься от опасности', 1),
#              ('укрыться от комаров', 1),
#              ('финансировать 0 ремонт', 1),
#              ('отреставрировать 0 плотины', 1),
#              ('извещать в форме', 1),
#              ('извещать 0 работника', 1),
#              ('извещать о частях', 1),
#              ('складывать 0 раз', 1),
#              ('складывать 0 товары', 1),
#              ('складывать при посещении', 1),
#              ('складывать в пакеты', 1),
#              ('задача—уберечь 0 детей', 1),
#              ('задача—уберечь от голода', 1),
#              ('восстановиться после разрухи', 1),
#              ('не_увидеть под окнами', 1),
#              ('не_увидеть 0 пожар', 1),
#              ('не_увидеть 0 свечение', 1),
#              ('не_увидеть 0 автомобиль', 1),
#              ('не_увидеть 0 зарево', 1),
#              ('не_увидеть 0 вспышку', 1),
#              ('не_увидеть 0 утром', 1),
#              ('не_увидеть 0 точку', 1),
#              ('не_увидеть 0 примеры', 1),
#              ('не_увидеть 0 ребят', 1),
#              ('не_увидеть 0 толстушку', 1),
#              ('не_увидеть 0 глазами', 1),
#              ('не_увидеть 0 год', 1),
#              ('не_увидеть 0 мастер-класс', 1),
#              ('не_увидеть 0 маму', 1),
#              ('не_увидеть 0 папу', 1),
#              ('не_увидеть 0 изменения', 1),
#              ('не_увидеть 0 снимки', 1),
#              ('не_увидеть 0 серию', 1),
#              ('не_увидеть 0 магазины', 1),
#              ('не_увидеть 0 пары', 1),
#              ('не_увидеть 0 стены', 1),
#              ('не_увидеть 0 работников', 1),
#              ('не_увидеть 0 шапку', 1),
#              ('не_увидеть 0 свет', 1),
#              ('не_увидеть 0 деревню', 1),
#              ('не_увидеть 0 автомашины', 1),
#              ('не_увидеть 0 леса', 1),
#              ('не_увидеть в окно', 1),
#              ('не_увидеть в часов', 1),
#              ('не_увидеть в поселке', 1),
#              ('не_увидеть в день', 1),
#              ('не_увидеть в интернете', 1),
#              ('не_увидеть в сети', 1),
#              ('не_увидеть в субботу', 1),
#              ('не_увидеть в крае', 1),
#              ('кормиться возле контейнеров', 1),
#              ('растаскивать 0 пакеты', 1),
#              ('растаскивать по поселку', 1),
#              ('отрезать 0 пункты', 1),
#              ('отрезать от цивилизации', 1),
#              ('затоплять 0 дома', 1),
#              ('разослать 0 письма', 1),
#              ('разослать 0 адресатам', 1),
#              ('не_привезти с мест', 1),
#              ('не_привезти 0 фотографии', 1),
#              ('выцвести с годами', 1),
#              ('фотографироваться на память', 1),
#              ('фотографироваться с удавом', 1),
#              ('не_питать 0 любви', 1),
#              ('не_открыться в здании', 1),
#              ('не_открыться в январе', 1),
#              ('не_открыться в году', 1),
#              ('не_открыться в сентябре', 1),
#              ('не_открыться в музее', 1),
#              ('не_открыться в библиотеке', 1),
#              ('не_открыться в центре', 1),
#              ('не_открыться в деревне', 1),
#              ('не_открыться в времени', 1),
#              ('не_открыться в начале', 1),
#              ('не_открыться в целях', 1),
#              ('не_открыться в поселке', 1),
#              ('не_открыться в селе', 1),
#              ('не_открыться в часов', 1),
#              ('не_открыться в районе', 1),
#              ('застрять в колеях', 1),
#              ('не_усугублять 0 ситуацию', 1),
#              ('раскидывать 0 снег', 1),
#              ('раскидывать на часть', 1),
#              ('переодеться в обувь', 1),
#              ('не_сравнять по мерке', 1),
#              ('попрактиковаться в решении', 1),
#              ('потечь 0 напасть', 1),
#              ('обрушиваться в сторону', 1),
#              ('проделывать 0 труд', 1),
#              ('не_вызывать 0 сомнений', 1),
#              ('соизмерить 0 правила', 1),
#              ('соизмерить с силами', 1),
#              ('посоветоваться с духовником', 1),
#              ('испросить 0 благословения', 1),
#              ('перевалить за градусов', 1),
#              ('замолвить 0 слово', 1),
#              ('выдворять 0 мигрантов', 1),
#              ('выдворять по решению', 1),
#              ('запоминаться на жизнь', 1),
#              ('восторгаться 0 чувствами', 1),
#              ('цитировать в зрелости', 1),
#              ('цитировать 0 евгения', 1),
#              ('поморщиться при упоминании', 1),
#              ('главенствовать в дни', 1),
#              ('зваться 0 татьяной', 1),
#              ('разваливаться на полу', 1),
#              ('помыть 0 руки', 1),
#              ('помещаться на ладони', 1),
#              ('прижиться в квартире', 1),
#              ('повышать 0 квалификацию', 1),
#              ('повышать на базе', 1),
#              ('собрания—сформировать 0 общество', 1),
#              ('не_состоять в мо', 1),
#              ('не_состоять в диспансере', 1),
#              ('не_состоять в основном', 1),
#              ('не_состоять в кцсон', 1),
#              ('не_состоять в москве', 1),
#              ('не_состоять в опубликовании', 1),
#              ('не_состоять в очереди', 1),
#              ('не_состоять в республике', 1),
#              ('не_состоять в наркодиспансере', 1),
#              ('не_состоять в центре', 1),
#              ('не_состоять в браке', 1),
#              ('не_состоять в инспекции', 1),
#              ('не_состоять в отношениях', 1),
#              ('щипать за нос', 1),
#              ('заносить 0 дело', 1),
#              ('заносить 0 снегом', 1),
#              ('заносить в время метелей', 1),
#              ('расчистить 0 снег', 1),
#              ('расчистить в деревнях', 1),
#              ('выпилить в райцентре', 1),
#              ('выпилить 0 иордань', 1),
#              ('окропить после молебна', 1),
#              ('окропить 0 водой', 1),
#              ('окропить 0 паству', 1),
#              ('лотереи—свч-печи—стать 0 обладательницей', 1),
#              ('девать 0 излишки', 1),
#              ('вываливать на часть', 1),
#              ('не_рубить 0 лес', 1),
#              ('не_рубить 0 островки', 1),
#              ('не_рубить 0 леса', 1),
#              ('омрачаться 0 начало', 1),
#              ('омрачаться 0 повышением', 1),
#              ('кликать 0 уборщиков', 1),
#              ('кликать 0 дворниками', 1),
#              ('захламить 0 площадками', 1),
#              ('не_возбуждаться в году', 1),
#              ('не_возбуждаться 0 дела', 1),
#              ('ужесточить 0 ответственность', 1),
#              ('изменять 0 место', 1),
#              ('изменять без согласия', 1),
#              ('поравняться 0 размерами', 1),
#              ('поравняться с хозяевами', 1),
#              ('не_настоящие—сделать 0 медведи', 1),
#              ('не_настоящие—сделать из снега', 1),
#              ('цель—предоставить 0 должникам', 1),
#              ('цель—предоставить 0 максимум', 1),
#              ('цель—предоставить в конце', 1),
#              ('расплатиться с задолженностями', 1),
#              ('грешить 0 пробелами', 1),
#              ('вселиться в квартиру', 1),
#              ('вселиться в время', 1),
#              ('не_сниматься с главы', 1),
#              ('не_сниматься 0 обязанность', 1),
#              ('полежать на диванчике', 1),
#              ('походить по комнате', 1),
#              ('походить 0 мин', 1),
#              ('склонить 0 главу', 1),
#              ('вальсировать 0 озвучиватьмультфильм', 1),
#              ('дивиться 0 счастью', 1),
#              ('подружиться с тобою', 1),
#              ('обаять 0 душой', 1),
#              ('не_нарушать 0 святости', 1),
#              ('не_нарушать 0 обет', 1),
#              ('не_выигрывать с поры', 1),
#              ('присваиваться 0 номер', 1),
#              ('присваиваться 0 человеку', 1),
#              ('присваиваться в ходе кампании', 1),
#              ('присваиваться при оформлении', 1),
#              ('миссию—вращать 0 барабан', 1),
#              ('печи—стать 0 обладателем', 1),
#              ('не_ожидать в районе', 1),
#              ('олегом—побывать в г', 1),
#              ('нагуляться по городу', 1),
#              ('сфотографироваться на память', 1),
#              ('нырять на снимке', 1),
#              ('нырять с тарзанки', 1),
#              ('нырять с высоты', 1),
#              ('нырять в воду', 1),
#              ('крепиться 0 люди', 1),
#              ('не_войти в число', 1),
#              ('не_войти в пост', 1),
#              ('не_войти в президиум', 1),
#              ('не_войти в состав', 1),
#              ('не_войти в дома', 1),
#              ('не_войти в быт', 1),
#              ('не_войти в историю', 1),
#              ('не_войти в комплекс', 1),
#              ('не_войти в этапе', 1),
#              ('не_войти в тройку', 1),
#              ('не_войти в пятерку', 1),
#              ('не_войти в зал', 1),
#              ('не_войти в жюри', 1),
#              ('не_войти в список', 1),
#              ('не_войти в радость', 1),
#              ('не_войти в программу', 1),
#              ('не_войти в эксплуатацию', 1),
#              ('не_войти в обиход', 1),
#              ('не_войти в группу', 1),
#              ('не_войти в инвестпрограмму', 1),
#              ('не_войти в году', 1),
#              ('не_войти в отряд', 1),
#              ('не_войти в категориях', 1),
#              ('не_войти в районе', 1),
#              ('не_войти в традицию', 1),
#              ('электромясорубки—стать 0 обладателем', 1),
#              ('зашифровать в выпусках', 1),
#              ('разбросать 0 слова', 1),
#              ('разбросать в номерах', 1),
#              ('разбросать по порядку', 1),
#              ('вчитываться в публикации', 1),
#              ('не_объявиться к сожалению', 1),
#              ('преобразить 0 вид', 1),
#              ('сочинять по словам', 1),
#              ('сочинять 0 семьей', 1),
#              ('усаживаться на ведерочки', 1),
#              ('пристраиваться на ящике', 1),
#              ('пересыхать за разговором', 1),
#              ('прозевать 0 поклевочку', 1)])

# %% [markdown]
# И напоследок -- бонус:
#
# ![бонус](bogadelnya.jpg)
